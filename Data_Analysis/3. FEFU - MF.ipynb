# %%
import pandas as pd
import numpy as np
import pickle

dataframes = pd.read_pickle('recom_data/user_category_dummy.pkl')

df_counts = dataframes['view_counts']
df_users = dataframes['users']

with open('recom_data/category_dict.pkl', 'rb') as handle:
    category_dict = pickle.load(handle)

item_similarity = pd.read_pickle('recom_data/item_similarity.pkl')

# %%
category_dict[855] = '유아동 도서'
category_dict[1071] = '교육 도서'
category_dict[1072] = '학습 도서'

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')

# %%
class MF():
    def __init__(self, ratings, K, alpha, beta, iterations, verbose=True):
        """
            K: 잠재요인(latent factor)의 수
            alpha: 학습률
            beta: 정규화 계수
            iterations: SGD의 계산을 할 때의 반복 횟수
            verbose: SGD의 중간 학습과정 출력 여부
        """
        self.R = np.array(ratings)
        
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id])
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)
        
        self.num_users, self.num_items = np.shape(self.R)
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations
        self.verbose = verbose
        
    def rmse(self):
        """
            현재의 P행렬과 Q행렬을 가지고 Root Mean Squared Error(RMSE)를 계산
        """
        xs, ys = self.R.nonzero()
        # R에서 평점이 있는 (0이 아닌) 요소의 인덱스를 저장
        self.predictions = []
        self.errors = []
        for x, y in zip(xs, ys):
            # 평점이 존재하는 요소 (사용자 x, 아이템 y) 각각에 대해 아래 코드를 실행
            prediction = self.get_prediction(x, y)
            # 사용자 x, 아이템 y에 대한 평점 예측치를 계산
            self.predictions.append(prediction)
            # 예측값을 리스트에 추가
            self.errors.append(self.R[x, y] - prediction)
            # 실제값과 예측값의 차이를 계산해서 오차값 리스트에 추가
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        # errors를 사용해서 RMSE를 계산
        return np.sqrt(np.mean(self.errors**2))
    
    def train(self):
        """
            정해진 횟수만큼 반복하며 P, Q, bu, bd 값을 업데이트하는 함수
        """
        # Initializing user-feature and movie-feature matrix
        # P, Q 행렬을 임의의 값으로 채움
        # 평균이 0, 표준편차가 10/K인 정규분포를 갖는 난수로 초기화
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))
        
        # Initializing the bias terms
        # 사용자 평가 경향(bu)를 0으로 초기화 / 크기는 사용자 수 (num_users)
        # 아이템 평가 경향(bd)를 0으로 초기화 / 크기는 아이템 수 (num_items)
        # 전체 평균 b를 구해서 저장
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items)
        self.b = np.mean(self.R[self.R.nonzero()])
        
        # List of training samples
        # 평점 행렬에서 값이 존재하는 요소의 인덱스들을 가져옴
        # SGD를 적용할 대상 (평점이 있는 요소의 인덱스와 평점)을 리스트로 저장
        rows, columns = self.R.nonzero()
        self.samples = [(i, j, self.R[i,j]) for i, j in zip(rows, columns)]
        
        # Stochastic gardient descent for given number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            # samples를 임의로 섞음 => 어디서 시작하는지에 따라 수렴의 속도가 달라짐
            # 매 반복마다 다양한 시작점에서 시작하기!
            self.sgd()
            # sgd를 실행 / P, Q, bu, bd가 업데이트 됨
            rmse = self.rmse()
            training_process.append((i+1, rmse))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print("반복: {0}; Train RMSE = {1:0.4f}".format(i+1, rmse))
        return training_process
    
    def get_prediction (self, i, j):
        """
            Rating prediction for user i and item j
            사용자 i의 아이템 j에 대한 평점을 예측하는 함수
        """
        prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
        return prediction
        
    def get_one_prediction(self, user_id, item_id):
        return self.get_prediction(self.user_id_index[user_id], self.item_id_index[item_id])
    
    def full_prediction(self):
        return self.b + self.b_u[:, np.newaxis] + self.b_d[np.newaxis, :] + self.P.dot(self.Q.T)

    def sgd(self):
        """
            Stochastic gardient descent to get optimized P and Q matrix
        """
        for i, j, r in self.samples:
            # samples에 있는 각 사용자-아이템-평점 세트에 대해서 SGD를 적용
            prediction = self.get_prediction(i, j)
            # 사용자 i, 아이템 j에 대한 평점 예측치를 구함
            e = (r - prediction)
            # 실제 평점 r과 비교해서 오차를 구함
            
            self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
            self.b_d[j] += self.alpha * (e - self.beta * self.b_d[j])
            # 사용자 평가 경향, 아이템 평가 경향 업데이트
            
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i, :])
            self.Q[j, :] += self.alpha * (e * self.P[i, :] - self.beta * self.Q[j, :])

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')
R_temp = view_matrix.fillna(0)
mf = MF(R_temp, K=100, alpha=0.01, beta=0.2, iterations=100, verbose=True)
# 인자 40개 / 반복 50회 / 학습률 0.001 / 정규화 계수 0.02로 모델을 학습합니다.
mf.train()
print(' ')
# Out:
# 반복: 10; Train RMSE = 0.8524
# 반복: 20; Train RMSE = 0.8518
# 반복: 30; Train RMSE = 0.8510
# 반복: 40; Train RMSE = 0.8473
# 반복: 50; Train RMSE = 0.8388
# 반복: 60; Train RMSE = 0.8314
# 반복: 70; Train RMSE = 0.8273
# 반복: 80; Train RMSE = 0.8248
# 반복: 90; Train RMSE = 0.8228
# 반복: 100; Train RMSE = 0.8213

# %%
print(mf.full_prediction())
# 전체 user-category의 예측값들입니다.
# Out:
# [[2.00167827 2.09482795 2.04042982 ... 2.53493103 2.13708008 2.15841162]
#  [1.73322405 1.77027175 1.78761272 ... 1.91051032 1.59569422 1.62750269]
#  [1.98729984 2.01449734 2.04809963 ... 2.09834859 1.80355931 1.83522653]
#  ...
#  [2.20382599 2.21004035 2.27720565 ... 2.18366077 1.92753196 1.95949675]
#  [2.20944556 2.21613093 2.28278798 ... 2.192187   1.93544577 1.96727523]
#  [2.20484414 2.21121158 2.27818863 ... 2.18560839 1.92925802 1.96119338]]

# %%
testers = [
    {'user_id': 90001,'gender': '남성','age': 17}, {'user_id': 90081,'gender': '남성','age': 22}, {'user_id': 90161,'gender': '남성','age': 32}, {'user_id': 90221,'gender': '남성','age': 42}, {'user_id': 90281,'gender': '남성','age': 52}, {'user_id': 90341,'gender': '남성','age': 62}, {'user_id': 90401,'gender': '남성','age': 72},
    {'user_id': 90501,'gender': '여성','age': 12}, {'user_id': 90521,'gender': '여성','age': 22}, {'user_id': 90541,'gender': '여성','age': 32}, {'user_id': 90561,'gender': '여성','age': 42}, {'user_id': 90581,'gender': '여성','age': 52}, {'user_id': 90601,'gender': '여성','age': 62}, {'user_id': 90621,'gender': '여성','age': 72}
]

# 각각의 그룹에서 한명씩 유저를 데려오고... 그 유저의 추천 카테고리를 출력해봤습니다.
# 그룹화가 아니라 개인화 추천입니다!!! 같은 그룹이어도 다른 추천 결과가 나옵니다.
for tester in testers:
    print(tester['gender'], tester['age'])
    temp_data = dict()
    
    # 전체 카테고리에 대해 예측값을 계산합니다.
    for category in R_temp:
        temp_data[category] = mf.get_one_prediction(tester['user_id'], category)

    # 예측값을 기준으로 정렬합니다.
    recomm_df = pd.DataFrame.from_dict([temp_data]).T.reset_index().rename(columns={'index': 'category', 0: 'pred'})
    temp_recomm_df = recomm_df.sort_values(by='pred', ascending=False)
    temp_recomm_df['category'] = temp_recomm_df['category'].map(lambda x: category_dict[x])
    print(temp_recomm_df)
# Out:
# 남성 17
#       category      pred
# 420      기타 문구  2.534931
# 419      사무 용품  2.423824
# 418      문구 용품  2.384112
# 3      여성 언더웨어  2.355415
# 412      기타 도서  2.323497
# ..         ...       ...
# 238  기타 관상어 용품  1.413329
# 264   기타 세탁 용품  1.402660
# 248  기타 자동차 용품  1.395205
# 247      안전 용품  1.391772
# 243        장난감  1.391548
#
# [423 rows x 2 columns]
# 남성 22
#       category      pred
# 327         인형  2.573523
# 320     임상부 용품  2.569935
# 3      여성 언더웨어  2.540266
# 8           기타  2.509890
# 319      수유 용품  2.485522
# ..         ...       ...
# 279     세제/세정제  1.671982
# 247      안전 용품  1.665354
# 243        장난감  1.662246
# 264   기타 세탁 용품  1.658584
# 248  기타 자동차 용품  1.657098
#
# [423 rows x 2 columns]
# 남성 32
#      category      pred
# 327        인형  2.773409
# 320    임상부 용품  2.718565
# 298     아기 간식  2.706104
# 319     수유 용품  2.662716
# 300       물티슈  2.651828
# ..        ...       ...
# 230        목공  1.724759
# 234  프라모델/피규어  1.719485
# 405     학습/교육  1.712060
# 235    기타 수집품  1.662006
# 410        잡지  1.644596
#
# [423 rows x 2 columns]
# 남성 42
#       category      pred
# 327         인형  2.379723
# 320     임상부 용품  2.378837
# 3      여성 언더웨어  2.338385
# 8           기타  2.309896
# 319      수유 용품  2.295762
# ..         ...       ...
# 279     세제/세정제  1.486945
# 247      안전 용품  1.481321
# 243        장난감  1.475655
# 264   기타 세탁 용품  1.475130
# 248  기타 자동차 용품  1.472059
#
# [423 rows x 2 columns]
# 남성 52
#       category      pred
# 420      기타 문구  3.023978
# 419      사무 용품  2.929418
# 418      문구 용품  2.854840
# 412      기타 도서  2.810675
# 406     소설/만화책  2.778327
# ..         ...       ...
# 238  기타 관상어 용품  1.737417
# 243        장난감  1.731901
# 264   기타 세탁 용품  1.731881
# 248  기타 자동차 용품  1.724415
# 247      안전 용품  1.718212
#
# [423 rows x 2 columns]
# 남성 62
#      category      pred
# 320    임상부 용품  2.592962
# 327        인형  2.538612
# 3     여성 언더웨어  2.514173
# 319     수유 용품  2.506629
# 6       남성 잠옷  2.471393
# ..        ...       ...
# 233     퍼즐/블록  1.738893
# 267   당뇨관리 용품  1.737293
# 243       장난감  1.729418
# 234  프라모델/피규어  1.722130
# 235    기타 수집품  1.684183
#
# [423 rows x 2 columns]
# 남성 72
#       category      pred
# 320     임상부 용품  2.631685
# 327         인형  2.613346
# 3      여성 언더웨어  2.554228
# 319      수유 용품  2.550995
# 8           기타  2.523531
# ..         ...       ...
# 264   기타 세탁 용품  1.758810
# 248  기타 자동차 용품  1.749118
# 234   프라모델/피규어  1.744137
# 243        장난감  1.742617
# 235     기타 수집품  1.709271
#
# [423 rows x 2 columns]
# 여성 12
#       category      pred
# 327         인형  2.644797
# 320     임상부 용품  2.638272
# 319      수유 용품  2.562309
# 3      여성 언더웨어  2.556480
# 8           기타  2.541914
# ..         ...       ...
# 264   기타 세탁 용품  1.735692
# 234   프라모델/피규어  1.734046
# 248  기타 자동차 용품  1.730435
# 243        장난감  1.724753
# 235     기타 수집품  1.696376
#
# [423 rows x 2 columns]
# 여성 22
#       category      pred
# 327         인형  2.612251
# 320     임상부 용품  2.590726
# 319      수유 용품  2.516865
# 298      아기 간식  2.511025
# 3      여성 언더웨어  2.509950
# ..         ...       ...
# 236     관상어 사료  1.694193
# 248  기타 자동차 용품  1.690222
# 234   프라모델/피규어  1.684999
# 243        장난감  1.684071
# 235     기타 수집품  1.643195
#
# [423 rows x 2 columns]
# 여성 32
#       category      pred
# 320     임상부 용품  2.205837
# 3      여성 언더웨어  2.196764
# 327         인형  2.156950
# 6        남성 잠옷  2.148570
# 8           기타  2.120943
# ..         ...       ...
# 279     세제/세정제  1.336055
# 264   기타 세탁 용품  1.317715
# 247      안전 용품  1.317015
# 243        장난감  1.316048
# 248  기타 자동차 용품  1.311062
#
# [423 rows x 2 columns]
# 여성 42
#       category      pred
# 3      여성 언더웨어  2.212561
# 420      기타 문구  2.186981
# 320     임상부 용품  2.168038
# 6        남성 잠옷  2.163155
# 8           기타  2.121069
# ..         ...       ...
# 236     관상어 사료  1.310912
# 264   기타 세탁 용품  1.292626
# 247      안전 용품  1.289896
# 248  기타 자동차 용품  1.288059
# 243        장난감  1.286592
#
# [423 rows x 2 columns]
# 여성 52
#       category      pred
# 327         인형  2.585473
# 320     임상부 용품  2.583472
# 3      여성 언더웨어  2.508271
# 319      수유 용품  2.505684
# 8           기타  2.491054
# ..         ...       ...
# 264   기타 세탁 용품  1.695185
# 234   프라모델/피규어  1.689774
# 248  기타 자동차 용품  1.688687
# 243        장난감  1.683170
# 235     기타 수집품  1.652609
#
# [423 rows x 2 columns]
# 여성 62
#       category      pred
# 3      여성 언더웨어  2.548288
# 420      기타 문구  2.515808
# 320     임상부 용품  2.500575
# 6        남성 잠옷  2.497461
# 8           기타  2.461379
# ..         ...       ...
# 238  기타 관상어 용품  1.637548
# 243        장난감  1.620026
# 264   기타 세탁 용품  1.618388
# 247      안전 용품  1.617149
# 248  기타 자동차 용품  1.615034
#
# [423 rows x 2 columns]
# 여성 72
#      category      pred
# 327        인형  2.699696
# 320    임상부 용품  2.650183
# 298     아기 간식  2.635934
# 319     수유 용품  2.593038
# 300       물티슈  2.580214
# ..        ...       ...
# 230        목공  1.663352
# 234  프라모델/피규어  1.657266
# 405     학습/교육  1.646906
# 235    기타 수집품  1.602596
# 410        잡지  1.582706
#
# [423 rows x 2 columns]

# %%
# 아래는 테스트중인 코드입니다. (svd 알고리즘) / https://www.fun-coding.org/recommend_basic6.html

# %%
view_matrix = view_matrix.fillna(0)
matrix_values = view_matrix.values
user_view_mean = np.mean(matrix_values, axis=1)

matrix_user_mean = matrix_values - user_view_mean.reshape(-1, 1)

# %%
from scipy.sparse.linalg import svds

user, sigma, vt = svds(matrix_user_mean, k = 15)
sigma = np.diag(sigma)

svd_user_prediction = np.dot(np.dot(user, sigma), vt) + user_view_mean.reshape(-1, 1)

# %%
test = list(category_dict.items())
test.sort(key=lambda x:x[0])
test2 = [x[1] for x in test]

results = []
for i in range(0, 1140, 20):
    result = svd_user_prediction[i]
    result_df = pd.DataFrame(result, columns=['pred'])
    result_df['category'] = result_df.index
    result_df['category'] = result_df['category'].apply(lambda x: test2[x])
    result_df = result_df.sort_values(by='pred', ascending=False)
    results.append([df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'], result_df])

results.sort(key=lambda x: x[0])
for result in results:
    print(result[0], result[1], result[2])
    print(result[3])
# Out:
# 90001 M 10
#          pred category
# 328  2.967099      수영모
# 329  2.900387      수영복
# 343  2.798448      야구공
# 344  2.606528      글러브
# 362  2.462636      스쿼시
# ..        ...      ...
# 3   -0.214905  여성 언더웨어
# 384 -0.232075   낚시 소모품
# 419 -0.232802    사무 용품
# 410 -0.262042       잡지
# 404 -0.366060    교육 도서
#
# [423 rows x 2 columns]
# 90021 M 10
#          pred  category
# 15   2.948289   남성 캐주얼화
# 5    2.576599     남성 하의
# 16   2.425680    남성 운동화
# 4    2.250605     남성 상의
# 31   2.211351    남성용 모자
# ..        ...       ...
# 368 -0.351347     무술 용품
# 366 -0.366487     보호 용품
# 410 -0.381384        잡지
# 347 -0.426180  기타 야구 용품
# 404 -0.631451     교육 도서
#
# [423 rows x 2 columns]
# 90041 M 10
#          pred    category
# 386  2.069063          텐트
# 383  1.937576         낚시대
# 377  1.819627       스키 장비
# 376  1.798753     스노보드 장비
# 329  1.790127         수영복
# ..        ...         ...
# 40  -0.205032         목걸이
# 400 -0.226480        요가매트
# 397 -0.240846      스케이트보드
# 399 -0.244424  기타 스케이트 용품
# 398 -0.258584     인라인스케이트
#
# [423 rows x 2 columns]
# 90061 M 10
#          pred  category
# 217  2.060784       카페트
# 211  2.049875        벽지
# 219  2.028142        기타
# 223  2.027776        시계
# 212  1.996754        타일
# ..        ...       ...
# 343 -0.144261       야구공
# 113 -0.147339       피쳐폰
# 116 -0.156983   휴대폰 충전기
# 360 -0.159376      배드민턴
# 330 -0.164618  기타 수영 용품
#
# [423 rows x 2 columns]
# 90081 M 20
#          pred    category
# 5    1.614117       남성 하의
# 406  1.598054      소설/만화책
# 417  1.593058       필기 용품
# 418  1.568600       문구 용품
# 412  1.541399       기타 도서
# ..        ...         ...
# 133 -0.124188         복합기
# 105 -0.148914       헤어 왁스
# 107 -0.149835  기타 헤어 스타일링
# 109 -0.150781       남성 향수
# 106 -0.153766     헤어 스프레이
#
# [423 rows x 2 columns]
# 90101 M 20
#          pred  category
# 405  2.276708     학습 도서
# 406  2.242593    소설/만화책
# 418  2.176668     문구 용품
# 408  2.117260  문학/과학/경영
# 412  2.057311     기타 도서
# ..        ...       ...
# 7   -0.411337   남성 언더웨어
# 6   -0.442744     남성 잠옷
# 2   -0.454467     여성 잠옷
# 8   -0.456582        기타
# 3   -0.470185   여성 언더웨어
#
# [423 rows x 2 columns]
# 90121 M 20
#          pred  category
# 406  1.989587    소설/만화책
# 420  1.888675     기타 문구
# 418  1.867014     문구 용품
# 408  1.833324  문학/과학/경영
# 417  1.655494     필기 용품
# ..        ...       ...
# 421 -0.545266     화방 용품
# 415 -0.562867      블루레이
# 416 -0.567553     기타 음반
# 413 -0.622036        음반
# 414 -0.635760       DVD
#
# [423 rows x 2 columns]
# 90141 M 20
#          pred  category
# 119  2.493408    스마트 밴드
# 118  2.453959    스마트 워치
# 113  2.413380       피쳐폰
# 121  2.369880        PC
# 127  2.292763    태블릿 PC
# ..        ...       ...
# 54  -0.235262        기타
# 183 -0.253132     헤어 케어
# 186 -0.259160  기타 미용 가전
# 184 -0.264181     두피 케어
# 185 -0.267237     피부 케어
#
# [423 rows x 2 columns]
# 90161 M 30
#          pred  category
# 386  2.318000        텐트
# 373  2.293924       등산화
# 375  2.162310  기타 등산 용품
# 372  2.145189     등산 의류
# 388  2.041090  기타 캠핑 용품
# ..        ...       ...
# 349 -0.393639       농구화
# 353 -0.394085       배구화
# 348 -0.406764       농구공
# 352 -0.435487       배구공
# 355 -0.435640  기타 배구 용품
#
# [423 rows x 2 columns]
# 90181 M 30
#          pred category
# 43   1.908819  기타 액세서리
# 38   1.895502       반지
# 101  1.880468    샴푸/린스
# 40   1.865591      목걸이
# 50   1.861804    여성 양말
# ..        ...      ...
# 6   -0.102243    남성 잠옷
# 404 -0.130026    교육 도서
# 422 -0.160414       기타
# 420 -0.212619    기타 문구
# 419 -0.283095    사무 용품
#
# [423 rows x 2 columns]
# 90201 M 30
#          pred  category
# 412  2.437766     기타 도서
# 409  2.301408    예술/디자인
# 411  2.236216      전공서적
# 410  2.077528        잡지
# 418  1.965439     문구 용품
# ..        ...       ...
# 22  -0.295628       중지갑
# 362 -0.300023       스쿼시
# 37  -0.306608     기타 소품
# 360 -0.369442      배드민턴
# 330 -0.387184  기타 수영 용품
#
# [423 rows x 2 columns]
# 90221 M 40
#          pred  category
# 217  2.103096       카페트
# 211  2.095295        벽지
# 200  2.094135  아동 책상/의자
# 223  2.075226        시계
# 191  2.049722        소파
# ..        ...       ...
# 233 -0.118503     퍼즐/블록
# 146 -0.126569       닌텐도
# 234 -0.128903  프라모델/피규어
# 143 -0.140841     PC 게임
# 145 -0.151408       PSP
#
# [423 rows x 2 columns]
# 90241 M 40
#          pred  category
# 405  2.570342     학습 도서
# 418  2.563201     문구 용품
# 406  2.421085    소설/만화책
# 118  2.303707    스마트 워치
# 408  2.290904  문학/과학/경영
# ..        ...       ...
# 2   -0.444607     여성 잠옷
# 8   -0.477275        기타
# 3   -0.484561   여성 언더웨어
# 1   -0.490353     여성 하의
# 0   -0.621139     여성 상의
#
# [423 rows x 2 columns]
# 90261 M 40
#          pred  category
# 402  2.380412   필라테스 용품
# 400  2.283069      요가매트
# 374  2.189707     등산 잡화
# 328  2.168335       수영모
# 373  2.139621       등산화
# ..        ...       ...
# 376 -0.203790   스노보드 장비
# 377 -0.211693     스키 장비
# 385 -0.236286  기타 낚시 용품
# 383 -0.306975       낚시대
# 384 -0.317196    낚시 소모품
#
# [423 rows x 2 columns]
# 90281 M 50
#          pred  category
# 113  2.422518       피쳐폰
# 121  2.337780        PC
# 127  2.314563    태블릿 PC
# 114  2.214366   휴대폰 케이스
# 122  2.210039     PC 부품
# ..        ...       ...
# 54  -0.210086        기타
# 183 -0.235152     헤어 케어
# 186 -0.239195  기타 미용 가전
# 185 -0.246496     피부 케어
# 184 -0.247898     두피 케어
#
# [423 rows x 2 columns]
# 90301 M 50
#          pred  category
# 412  3.005245     기타 도서
# 411  2.863944      전공서적
# 410  2.687823        잡지
# 409  2.606798    예술/디자인
# 407  2.554279  여행/취미/레저
# ..        ...       ...
# 360 -0.197267      배드민턴
# 14  -0.197426     남성 구두
# 15  -0.205737   남성 캐주얼화
# 16  -0.227736    남성 운동화
# 343 -0.257821       야구공
#
# [423 rows x 2 columns]
# 90321 M 50
#          pred  category
# 43   2.583227   기타 액세서리
# 50   2.550244     여성 양말
# 38   2.539177        반지
# 1    2.523780     여성 하의
# 10   2.493142   여성 캐주얼화
# ..        ...       ...
# 333 -0.155693     골프 가방
# 334 -0.158594  기타 골프 용품
# 331 -0.166841     골프 클럽
# 349 -0.169607       농구화
# 348 -0.171448       농구공
#
# [423 rows x 2 columns]
# 90341 M 60
#          pred  category
# 343  2.878648       야구공
# 328  2.872244       수영모
# 360  2.839331      배드민턴
# 330  2.631295  기타 수영 용품
# 329  2.626512       수영복
# ..        ...       ...
# 414 -0.527862       DVD
# 413 -0.535191        음반
# 409 -0.587977    예술/디자인
# 412 -0.693967     기타 도서
# 411 -0.740095      전공서적
#
# [423 rows x 2 columns]
# 90361 M 60
#          pred     category
# 327  2.083016           인형
# 304  2.068895  기타 유아 위생 용품
# 323  2.000834        완구/매트
# 303  1.991959     위생/건강 용품
# 298  1.989238        아기 간식
# ..        ...          ...
# 232 -0.171458        기타 공구
# 230 -0.173549           목공
# 231 -0.185850           접착
# 419 -0.220087        사무 용품
# 412 -0.245242        기타 도서
#
# [423 rows x 2 columns]
# 90381 M 60
#          pred  category
# 406  1.889010    소설/만화책
# 418  1.878595     문구 용품
# 420  1.736870     기타 문구
# 417  1.719973     필기 용품
# 408  1.643358  문학/과학/경영
# ..        ...       ...
# 413 -0.300034        음반
# 414 -0.305518       DVD
# 401 -0.316677     요가 용품
# 400 -0.334585      요가매트
# 402 -0.388798   필라테스 용품
#
# [423 rows x 2 columns]
# 90401 M 70
#          pred category
# 343  1.696232      야구공
# 328  1.687312      수영모
# 360  1.620502     배드민턴
# 329  1.536991      수영복
# 362  1.522090      스쿼시
# ..        ...      ...
# 422 -0.331455       기타
# 415 -0.353548     블루레이
# 414 -0.384855      DVD
# 416 -0.386071    기타 음반
# 413 -0.387136       음반
#
# [423 rows x 2 columns]
# 90421 M 70
#          pred  category
# 1    2.310834     여성 하의
# 43   2.277141   기타 액세서리
# 50   2.251135     여성 양말
# 38   2.237273        반지
# 10   2.199644   여성 캐주얼화
# ..        ...       ...
# 334 -0.151070  기타 골프 용품
# 333 -0.152482     골프 가방
# 331 -0.158242     골프 클럽
# 56  -0.200060    남성용 시계
# 419 -0.232788     사무 용품
#
# [423 rows x 2 columns]
# 90441 M 70
#          pred  category
# 223  1.683424        시계
# 217  1.677362       카페트
# 211  1.675594        벽지
# 200  1.653545  아동 책상/의자
# 187  1.626686        침대
# ..        ...       ...
# 252 -0.110385     기타 악기
# 251 -0.110947     건반 악기
# 1   -0.111587     여성 하의
# 4   -0.125554     남성 상의
# 5   -0.129531     남성 하의
#
# [423 rows x 2 columns]
# 90501 F 10
#          pred category
# 5    1.647313    남성 하의
# 15   1.612438  남성 캐주얼화
# 4    1.419968    남성 상의
# 16   1.373793   남성 운동화
# 31   1.235586   남성용 모자
# ..        ...      ...
# 134 -0.237739      프린터
# 136 -0.238965  네트워크 장비
# 401 -0.322389    요가 용품
# 402 -0.324300  필라테스 용품
# 400 -0.346465     요가매트
#
# [423 rows x 2 columns]
# 90521 F 10
#          pred     category
# 304  2.683293  기타 유아 위생 용품
# 327  2.678528           인형
# 323  2.582600        완구/매트
# 297  2.559627          이유식
# 298  2.555460        아기 간식
# ..        ...          ...
# 136 -0.173106      네트워크 장비
# 183 -0.236757        헤어 케어
# 186 -0.247374     기타 미용 가전
# 184 -0.260529        두피 케어
# 185 -0.260873        피부 케어
#
# [423 rows x 2 columns]
# 90541 F 10
#          pred  category
# 383  2.253323       낚시대
# 386  2.243876        텐트
# 377  2.078203     스키 장비
# 376  2.051863   스노보드 장비
# 373  1.974047       등산화
# ..        ...       ...
# 352 -0.407894       배구공
# 355 -0.407951  기타 배구 용품
# 349 -0.446797       농구화
# 348 -0.470526       농구공
# 328 -0.567243       수영모
#
# [423 rows x 2 columns]
# 90561 F 10
#          pred category
# 15   2.167108  남성 캐주얼화
# 16   1.840067   남성 운동화
# 5    1.745461    남성 하의
# 31   1.692771   남성용 모자
# 45   1.686563    남성 장갑
# ..        ...      ...
# 413 -0.282622       음반
# 416 -0.285301    기타 음반
# 414 -0.302370      DVD
# 1   -0.384594    여성 하의
# 0   -0.467065    여성 상의
#
# [423 rows x 2 columns]
# 90581 F 20
#          pred   category
# 418  2.477679      문구 용품
# 405  2.380521      학습 도서
# 406  2.374904     소설/만화책
# 417  2.343566      필기 용품
# 408  2.000248   문학/과학/경영
# ..        ...        ...
# 338 -0.257384        축구공
# 381 -0.277111   자전거 안전용품
# 379 -0.302743        자전거
# 382 -0.346776  기타 자전거 용품
# 20  -0.358513   기타 신발 용품
#
# [423 rows x 2 columns]
# 90601 F 20
#          pred  category
# 402  2.620976   필라테스 용품
# 328  2.571547       수영모
# 400  2.534274      요가매트
# 374  2.453597     등산 잡화
# 373  2.378177       등산화
# ..        ...       ...
# 383 -0.213285       낚시대
# 413 -0.221658        음반
# 417 -0.235671     필기 용품
# 408 -0.236439  문학/과학/경영
# 422 -0.249717        기타
#
# [423 rows x 2 columns]
# 90621 F 20
#          pred  category
# 113  1.940313       피쳐폰
# 121  1.932848        PC
# 127  1.917961    태블릿 PC
# 119  1.906034    스마트 밴드
# 131  1.856198       마우스
# ..        ...       ...
# 36  -0.229779       머플러
# 35  -0.230275       넥타이
# 51  -0.243672     남성 양말
# 19  -0.268428  신발 관리 용품
# 18  -0.280013   남성 기능성화
#
# [423 rows x 2 columns]
# 90641 F 20
#          pred  category
# 402  3.096646   필라테스 용품
# 400  3.021597      요가매트
# 328  2.695906       수영모
# 374  2.645767     등산 잡화
# 373  2.495156       등산화
# ..        ...       ...
# 385 -0.401524  기타 낚시 용품
# 339 -0.401560       축구화
# 384 -0.445165    낚시 소모품
# 338 -0.454641       축구공
# 383 -0.547466       낚시대
#
# [423 rows x 2 columns]
# 90661 F 30
#          pred  category
# 127  2.194628    태블릿 PC
# 119  2.071573    스마트 밴드
# 113  2.060423       피쳐폰
# 132  2.046066       키보드
# 129  2.013576       노트북
# ..        ...       ...
# 330 -0.244610  기타 수영 용품
# 3   -0.251771   여성 언더웨어
# 6   -0.267614     남성 잠옷
# 419 -0.796266     사무 용품
# 420 -1.202645     기타 문구
#
# [423 rows x 2 columns]
# 90681 F 30
#          pred    category
# 5    2.120492       남성 하의
# 1    2.007335       여성 하의
# 3    1.934945     여성 언더웨어
# 8    1.933009          기타
# 4    1.917306       남성 상의
# ..        ...         ...
# 105 -0.255569       헤어 왁스
# 107 -0.261156  기타 헤어 스타일링
# 106 -0.261553     헤어 스프레이
# 109 -0.261937       남성 향수
# 408 -0.268452    문학/과학/경영
#
# [423 rows x 2 columns]
# 90701 F 30
#          pred category
# 1    2.201622    여성 하의
# 0    2.085486    여성 상의
# 38   1.957125       반지
# 43   1.937910  기타 액세서리
# 40   1.936667      목걸이
# ..        ...      ...
# 15  -0.191348  남성 캐주얼화
# 118 -0.224371   스마트 워치
# 419 -0.236864    사무 용품
# 56  -0.277406   남성용 시계
# 420 -0.356006    기타 문구
#
# [423 rows x 2 columns]
# 90721 F 40
#          pred  category
# 15   2.183413   남성 캐주얼화
# 5    2.073246     남성 하의
# 16   1.830502    남성 운동화
# 4    1.784584     남성 상의
# 31   1.660991    남성용 모자
# ..        ...       ...
# 401 -0.306083     요가 용품
# 388 -0.316126  기타 캠핑 용품
# 400 -0.327518      요가매트
# 387 -0.367891        랜턴
# 386 -0.390128        텐트
#
# [423 rows x 2 columns]
# 90741 F 40
#          pred  category
# 178  2.161472       이어폰
# 167  2.116418  기타 주방 가전
# 175  2.109933  기타 생활 가전
# 166  2.072365      요리가전
# 169  2.052789      프로젝터
# ..        ...       ...
# 386 -0.164423        텐트
# 334 -0.173140  기타 골프 용품
# 332 -0.180062       골프공
# 333 -0.183201     골프 가방
# 331 -0.200591     골프 클럽
#
# [423 rows x 2 columns]
# 90761 F 40
#          pred  category
# 223  2.035284        시계
# 211  2.028398        벽지
# 217  2.013603       카페트
# 200  2.000113  아동 책상/의자
# 191  1.986614        소파
# ..        ...       ...
# 398 -0.195430   인라인스케이트
# 391 -0.200843        아대
# 390 -0.209163       볼링화
# 392 -0.213051  기타 볼링 용품
# 389 -0.216382       볼링공
#
# [423 rows x 2 columns]
# 90781 F 50
#          pred  category
# 418  3.236565     문구 용품
# 408  3.191309  문학/과학/경영
# 406  3.017232    소설/만화책
# 420  2.934016     기타 문구
# 417  2.920157     필기 용품
# ..        ...       ...
# 147 -0.299293       Wii
# 144 -0.303809   플레이스테이션
# 150 -0.317076     기타 게임
# 146 -0.354916       닌텐도
# 149 -0.358516    게임 타이틀
#
# [423 rows x 2 columns]
# 90801 F 50
#          pred    category
# 113  2.126733         피쳐폰
# 127  2.073253      태블릿 PC
# 121  2.053451          PC
# 145  1.984343         PSP
# 129  1.962500         노트북
# ..        ...         ...
# 421 -0.206506       화방 용품
# 209 -0.247051  기타 아웃도어 가구
# 208 -0.247051    야외테이블/의자
# 410 -0.278247          잡지
# 404 -0.314699       교육 도서
#
# [423 rows x 2 columns]
# 90821 F 50
#          pred     category
# 383  2.586934          낚시대
# 377  2.540114        스키 장비
# 376  2.500940      스노보드 장비
# 386  2.486812           텐트
# 378  2.249760  기타 스키/보드 용품
# ..        ...          ...
# 401 -0.256137        요가 용품
# 409 -0.289459       예술/디자인
# 404 -0.302039        교육 도서
# 400 -0.334238         요가매트
# 402 -0.342640      필라테스 용품
#
# [423 rows x 2 columns]
# 90841 F 60
#          pred   category
# 178  2.311978        이어폰
# 167  2.263758   기타 주방 가전
# 175  2.262063   기타 생활 가전
# 166  2.237135       요리가전
# 174  2.199599        청소기
# ..        ...        ...
# 334 -0.149999   기타 골프 용품
# 332 -0.153193        골프공
# 333 -0.157376      골프 가방
# 382 -0.157446  기타 자전거 용품
# 331 -0.172652      골프 클럽
#
# [423 rows x 2 columns]
# 90861 F 60
#          pred    category
# 217  2.358632         카페트
# 211  2.319138          벽지
# 223  2.307357          시계
# 200  2.286543    아동 책상/의자
# 219  2.253447          기타
# ..        ...         ...
# 231 -0.180187          접착
# 250 -0.193981  기타(guitar)
# 249 -0.195676         피아노
# 251 -0.196782       건반 악기
# 252 -0.204426       기타 악기
#
# [423 rows x 2 columns]
# 90881 F 60
#          pred category
# 405  2.039458    학습 도서
# 418  2.012045    문구 용품
# 406  1.915350   소설/만화책
# 412  1.851287    기타 도서
# 417  1.821100    필기 용품
# ..        ...      ...
# 55  -0.171131   여성용 시계
# 57  -0.191157    공용 시계
# 401 -0.204353    요가 용품
# 402 -0.231046  필라테스 용품
# 400 -0.233851     요가매트
#
# [423 rows x 2 columns]
# 90901 F 70
#          pred     category
# 418  2.313580        문구 용품
# 408  2.176339     문학/과학/경영
# 406  2.117947       소설/만화책
# 417  2.064051        필기 용품
# 304  1.878897  기타 유아 위생 용품
# ..        ...          ...
# 186 -0.190895     기타 미용 가전
# 146 -0.191149          닌텐도
# 149 -0.196897       게임 타이틀
# 185 -0.208168        피부 케어
# 184 -0.208759        두피 케어
#
# [423 rows x 2 columns]
# 90921 F 70
#          pred  category
# 5    3.102786     남성 하의
# 4    2.892251     남성 상의
# 3    2.517327   여성 언더웨어
# 8    2.496401        기타
# 6    2.468725     남성 잠옷
# ..        ...       ...
# 408 -0.195766  문학/과학/경영
# 421 -0.197012     화방 용품
# 413 -0.206986        음반
# 405 -0.237456     학습 도서
# 407 -0.250968  여행/취미/레저
#
# [423 rows x 2 columns]
# 90941 F 70
#          pred  category
# 406  2.620986    소설/만화책
# 418  2.457098     문구 용품
# 408  2.432378  문학/과학/경영
# 412  2.410655     기타 도서
# 417  2.409651     필기 용품
# ..        ...       ...
# 350 -0.283668     농구 의류
# 339 -0.286881       축구화
# 338 -0.296624       축구공
# 349 -0.351765       농구화
# 348 -0.359814       농구공
#
# [423 rows x 2 columns]
# 91001 C 100
#          pred     category
# 304  2.285676  기타 유아 위생 용품
# 327  2.276720           인형
# 323  2.208097        완구/매트
# 298  2.186752        아기 간식
# 297  2.172082          이유식
# ..        ...          ...
# 419 -0.216769        사무 용품
# 186 -0.218039     기타 미용 가전
# 185 -0.230520        피부 케어
# 184 -0.238587        두피 케어
# 412 -0.247740        기타 도서
#
# [423 rows x 2 columns]
# 91021 C 100
#          pred  category
# 276  2.138749     주방 잡화
# 239  2.136452    강아지 사료
# 240  2.116482    강아지 간식
# 243  2.112456       장난감
# 277  2.112076  기타 주방 용품
# ..        ...       ...
# 14  -0.190482     남성 구두
# 406 -0.191806    소설/만화책
# 411 -0.222027      전공서적
# 23  -0.226050       단지갑
# 420 -0.325923     기타 문구
#
# [423 rows x 2 columns]
# 91041 C 100
#          pred  category
# 372  2.410069     등산 의류
# 373  2.294645       등산화
# 375  2.241306  기타 등산 용품
# 379  2.184982       자전거
# 381  2.171932  자전거 안전용품
# ..        ...       ...
# 331 -0.288477     골프 클럽
# 339 -0.405238       축구화
# 338 -0.422791       축구공
# 349 -0.473942       농구화
# 348 -0.492590       농구공
#
# [423 rows x 2 columns]
# 91061 C 100
#          pred  category
# 200  2.213155  아동 책상/의자
# 191  2.162141        소파
# 199  2.120319  기타 수납 가구
# 211  2.114256        벽지
# 223  2.107540        시계
# ..        ...       ...
# 420 -0.214260     기타 문구
# 184 -0.442754     두피 케어
# 183 -0.495739     헤어 케어
# 186 -0.531171  기타 미용 가전
# 185 -0.590966     피부 케어
#
# [423 rows x 2 columns]
# 91081 C 100
#          pred  category
# 409  2.398318    예술/디자인
# 412  2.329273     기타 도서
# 418  2.292523     문구 용품
# 417  2.190816     필기 용품
# 408  2.159016  문학/과학/경영
# ..        ...       ...
# 361 -0.199720       테니스
# 343 -0.206353       야구공
# 328 -0.209615       수영모
# 360 -0.248619      배드민턴
# 362 -0.274604       스쿼시
#
# [423 rows x 2 columns]
# 91101 C 100
#          pred    category
# 178  2.134103         이어폰
# 175  2.090428    기타 생활 가전
# 167  2.084729    기타 주방 가전
# 169  2.060424        프로젝터
# 179  2.054653    기타 음향 가전
# ..        ...         ...
# 232 -0.247933       기타 공구
# 231 -0.258073          접착
# 251 -0.265688       건반 악기
# 209 -0.438135  기타 아웃도어 가구
# 208 -0.438135    야외테이블/의자
#
# [423 rows x 2 columns]
# 91121 C 100
#          pred    category
# 329  2.653963         수영복
# 328  2.576957         수영모
# 343  2.571199         야구공
# 344  2.470607         글러브
# 362  2.421665         스쿼시
# ..        ...         ...
# 372 -0.273594       등산 의류
# 395 -0.302662         스쿠터
# 399 -0.357998  기타 스케이트 용품
# 398 -0.366746     인라인스케이트
# 397 -0.368124      스케이트보드
#
# [423 rows x 2 columns]
# 91141 C 100
#          pred  category
# 3    1.386558   여성 언더웨어
# 6    1.380804     남성 잠옷
# 8    1.368662        기타
# 5    1.333426     남성 하의
# 4    1.271992     남성 상의
# ..        ...       ...
# 408 -0.356868  문학/과학/경영
# 119 -0.360717    스마트 밴드
# 56  -0.677045    남성용 시계
# 57  -0.723949     공용 시계
# 55  -0.737657    여성용 시계
#
# [423 rows x 2 columns]
# 91161 C 100
#          pred  category
# 104  2.225535  기타 헤어 케어
# 101  2.203876     샴푸/린스
# 90   2.161635   마사지크림/젤
# 62   2.137498    에센스/크림
# 97   2.132752    바디 클렌저
# ..        ...       ...
# 13  -0.265479   여성 기능성화
# 9   -0.291591     여성 구두
# 411 -0.352316      전공서적
# 412 -0.404872     기타 도서
# 42  -0.408889        팔찌
#
# [423 rows x 2 columns]
# 91181 C 100
#          pred category
# 113  2.316851      피쳐폰
# 121  2.305272       PC
# 122  2.232031    PC 부품
# 127  2.224073   태블릿 PC
# 145  2.204805      PSP
# ..        ...      ...
# 410 -0.428328       잡지
# 0   -0.478128    여성 상의
# 1   -0.504641    여성 하의
# 4   -0.580864    남성 상의
# 5   -0.706080    남성 하의
#
# [423 rows x 2 columns]
# 91201 C 100
#          pred   category
# 42   2.272128         팔찌
# 29   2.217431  기타 헤어액세서리
# 38   2.206681         반지
# 11   2.154579     여성 운동화
# 44   2.144707      여성 장갑
# ..        ...        ...
# 415 -0.396195       블루레이
# 413 -0.453109         음반
# 416 -0.468539      기타 음반
# 414 -0.473248        DVD
# 404 -0.650717      교육 도서
#
# [423 rows x 2 columns]
