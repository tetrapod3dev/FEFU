# %%
import pandas as pd
import numpy as np
import pickle

dataframes = pd.read_pickle('recom_data/user_category_dummy3.pkl')

df_counts = dataframes['view_counts']
df_users = dataframes['users']

with open('recom_data/category_dict.pkl', 'rb') as handle:
    category_dict = pickle.load(handle)

item_similarity = pd.read_pickle('recom_data/item_similarity.pkl')

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')

# %%
class MF():
    def __init__(self, ratings, K, alpha, beta, iterations, verbose=True):
        """
            K: 잠재요인(latent factor)의 수
            alpha: 학습률
            beta: 정규화 계수
            iterations: SGD의 계산을 할 때의 반복 횟수
            verbose: SGD의 중간 학습과정 출력 여부
        """
        self.R = np.array(ratings)
        
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id])
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)
        
        self.num_users, self.num_items = np.shape(self.R)
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations
        self.verbose = verbose
        
    def rmse(self):
        """
            현재의 P행렬과 Q행렬을 가지고 Root Mean Squared Error(RMSE)를 계산
        """
        xs, ys = self.R.nonzero()
        # R에서 평점이 있는 (0이 아닌) 요소의 인덱스를 저장
        self.predictions = []
        self.errors = []
        for x, y in zip(xs, ys):
            # 평점이 존재하는 요소 (사용자 x, 아이템 y) 각각에 대해 아래 코드를 실행
            prediction = self.get_prediction(x, y)
            # 사용자 x, 아이템 y에 대한 평점 예측치를 계산
            self.predictions.append(prediction)
            # 예측값을 리스트에 추가
            self.errors.append(self.R[x, y] - prediction)
            # 실제값과 예측값의 차이를 계산해서 오차값 리스트에 추가
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        # errors를 사용해서 RMSE를 계산
        return np.sqrt(np.mean(self.errors**2))
    
    def train(self):
        """
            정해진 횟수만큼 반복하며 P, Q, bu, bd 값을 업데이트하는 함수
        """
        # Initializing user-feature and movie-feature matrix
        # P, Q 행렬을 임의의 값으로 채움
        # 평균이 0, 표준편차가 10/K인 정규분포를 갖는 난수로 초기화
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))
        
        # Initializing the bias terms
        # 사용자 평가 경향(bu)를 0으로 초기화 / 크기는 사용자 수 (num_users)
        # 아이템 평가 경향(bd)를 0으로 초기화 / 크기는 아이템 수 (num_items)
        # 전체 평균 b를 구해서 저장
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items)
        self.b = np.mean(self.R[self.R.nonzero()])
        
        # List of training samples
        # 평점 행렬에서 값이 존재하는 요소의 인덱스들을 가져옴
        # SGD를 적용할 대상 (평점이 있는 요소의 인덱스와 평점)을 리스트로 저장
        rows, columns = self.R.nonzero()
        self.samples = [(i, j, self.R[i,j]) for i, j in zip(rows, columns)]
        
        # Stochastic gardient descent for given number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            # samples를 임의로 섞음 => 어디서 시작하는지에 따라 수렴의 속도가 달라짐
            # 매 반복마다 다양한 시작점에서 시작하기!
            self.sgd()
            # sgd를 실행 / P, Q, bu, bd가 업데이트 됨
            rmse = self.rmse()
            training_process.append((i+1, rmse))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print("반복: {0}; Train RMSE = {1:0.4f}".format(i+1, rmse))
        return training_process
    
    def get_prediction (self, i, j):
        """
            Rating prediction for user i and item j
            사용자 i의 아이템 j에 대한 평점을 예측하는 함수
        """
        prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
        return prediction
        
    def get_one_prediction(self, user_id, item_id):
        return self.get_prediction(self.user_id_index[user_id], self.item_id_index[item_id])
    
    def full_prediction(self):
        return self.b + self.b_u[:, np.newaxis] + self.b_d[np.newaxis, :] + self.P.dot(self.Q.T)

    def sgd(self):
        """
            Stochastic gardient descent to get optimized P and Q matrix
        """
        for i, j, r in self.samples:
            # samples에 있는 각 사용자-아이템-평점 세트에 대해서 SGD를 적용
            prediction = self.get_prediction(i, j)
            # 사용자 i, 아이템 j에 대한 평점 예측치를 구함
            e = (r - prediction)
            # 실제 평점 r과 비교해서 오차를 구함
            
            self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
            self.b_d[j] += self.alpha * (e - self.beta * self.b_d[j])
            # 사용자 평가 경향, 아이템 평가 경향 업데이트
            
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i, :])
            self.Q[j, :] += self.alpha * (e * self.P[i, :] - self.beta * self.Q[j, :])

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')
R_temp = view_matrix.fillna(0)
mf = MF(R_temp, K=100, alpha=0.01, beta=0.2, iterations=100, verbose=True)
# 인자 40개 / 반복 50회 / 학습률 0.001 / 정규화 계수 0.02로 모델을 학습합니다.
mf.train()
print(' ')
# Out:
# 반복: 10; Train RMSE = 0.8660
# 반복: 20; Train RMSE = 0.8645
# 반복: 30; Train RMSE = 0.8632
# 반복: 40; Train RMSE = 0.8581
# 반복: 50; Train RMSE = 0.8479
# 반복: 60; Train RMSE = 0.8400
# 반복: 70; Train RMSE = 0.8357
# 반복: 80; Train RMSE = 0.8328
# 반복: 90; Train RMSE = 0.8309
# 반복: 100; Train RMSE = 0.8294

# %%
print(mf.full_prediction())
# 전체 user-category의 예측값들입니다.
# Out:
# [[1.90911285 1.92306463 2.03961867 ... 2.2366305  1.85770386 1.87148979]
#  [2.26065369 2.28654936 2.43037866 ... 2.64670931 2.23876555 2.23480832]
#  [1.91853277 1.9524703  2.05416874 ... 2.15235855 1.80949829 1.76922399]
#  ...
#  [1.44397159 1.50183204 1.51609749 ... 1.3678365  1.13431666 1.00397158]
#  [1.44089223 1.49876127 1.51290293 ... 1.36432526 1.13100963 1.00058551]
#  [1.44424659 1.50217184 1.51625641 ... 1.36740024 1.1342188  1.00366116]]

# %%
testers = [
    {'user_id': 90001,'gender': '남성','age': 17}, {'user_id': 90081,'gender': '남성','age': 22}, {'user_id': 90161,'gender': '남성','age': 32}, {'user_id': 90221,'gender': '남성','age': 42}, {'user_id': 90281,'gender': '남성','age': 52}, {'user_id': 90341,'gender': '남성','age': 62}, {'user_id': 90401,'gender': '남성','age': 72},
    {'user_id': 90501,'gender': '여성','age': 12}, {'user_id': 90521,'gender': '여성','age': 22}, {'user_id': 90541,'gender': '여성','age': 32}, {'user_id': 90561,'gender': '여성','age': 42}, {'user_id': 90581,'gender': '여성','age': 52}, {'user_id': 90601,'gender': '여성','age': 62}, {'user_id': 90621,'gender': '여성','age': 72}
]

# 각각의 그룹에서 한명씩 유저를 데려오고... 그 유저의 추천 카테고리를 출력해봤습니다.
# 그룹화가 아니라 개인화 추천입니다!!! 같은 그룹이어도 다른 추천 결과가 나옵니다.
for tester in testers:
    print(tester['gender'], tester['age'])
    temp_data = dict()
    
    # 전체 카테고리에 대해 예측값을 계산합니다.
    for category in R_temp:
        temp_data[category] = mf.get_one_prediction(tester['user_id'], category)

    # 예측값을 기준으로 정렬합니다.
    recomm_df = pd.DataFrame.from_dict([temp_data]).T.reset_index().rename(columns={'index': 'category', 0: 'pred'})
    temp_recomm_df = recomm_df.sort_values(by='pred', ascending=False)
    temp_recomm_df['category'] = temp_recomm_df['category'].map(lambda x: category_dict[x])
    print(temp_recomm_df)
# Out:
# 남성 17
#       category      pred
# 420      기타 문구  2.236631
# 7      남성 언더웨어  2.148835
# 408   문학/과학/경영  2.134182
# 6        남성 잠옷  2.133255
# 3      여성 언더웨어  2.120564
# ..         ...       ...
# 243        장난감  1.228271
# 245      세차 용품  1.215497
# 257         비데  1.212796
# 258         욕조  1.211935
# 248  기타 자동차 용품  1.191708
#
# [423 rows x 2 columns]
# 남성 22
#       category      pred
# 3      여성 언더웨어  2.445759
# 303   위생/건강 용품  2.441009
# 7      남성 언더웨어  2.412480
# 6        남성 잠옷  2.405142
# 315     유아동 의류  2.397305
# ..         ...       ...
# 245      세차 용품  1.544986
# 232      기타 공구  1.537590
# 258         욕조  1.527778
# 257         비데  1.524593
# 248  기타 자동차 용품  1.508205
#
# [423 rows x 2 columns]
# 남성 32
#       category      pred
# 315     유아동 의류  2.770781
# 303   위생/건강 용품  2.735368
# 325    유아동 주얼리  2.726737
# 3      여성 언더웨어  2.693417
# 145        PSP  2.683168
# ..         ...       ...
# 230         목공  1.844456
# 258         욕조  1.825528
# 257         비데  1.814941
# 232      기타 공구  1.813387
# 248  기타 자동차 용품  1.810875
#
# [423 rows x 2 columns]
# 남성 42
#       category      pred
# 420      기타 문구  2.396226
# 3      여성 언더웨어  2.356161
# 7      남성 언더웨어  2.349441
# 6        남성 잠옷  2.347355
# 303   위생/건강 용품  2.308011
# ..         ...       ...
# 243        장난감  1.431485
# 245      세차 용품  1.414007
# 257         비데  1.411211
# 258         욕조  1.408857
# 248  기타 자동차 용품  1.386359
#
# [423 rows x 2 columns]
# 남성 52
#       category      pred
# 420      기타 문구  2.478952
# 7      남성 언더웨어  2.452769
# 3      여성 언더웨어  2.433643
# 6        남성 잠옷  2.429771
# 336      운동 용품  2.381472
# ..         ...       ...
# 232      기타 공구  1.573689
# 245      세차 용품  1.567418
# 258         욕조  1.556184
# 257         비데  1.552904
# 248  기타 자동차 용품  1.537971
#
# [423 rows x 2 columns]
# 남성 62
#       category      pred
# 315     유아동 의류  2.553972
# 303   위생/건강 용품  2.544604
# 3      여성 언더웨어  2.537522
# 325    유아동 주얼리  2.520205
# 7      남성 언더웨어  2.506816
# ..         ...       ...
# 245      세차 용품  1.684962
# 258         욕조  1.661075
# 232      기타 공구  1.660761
# 257         비데  1.652870
# 248  기타 자동차 용품  1.645509
#
# [423 rows x 2 columns]
# 남성 72
#       category      pred
# 315     유아동 의류  2.741540
# 145        PSP  2.733555
# 325    유아동 주얼리  2.679323
# 193   기타 거실 가구  2.661309
# 147        Wii  2.653268
# ..         ...       ...
# 258         욕조  1.816582
# 248  기타 자동차 용품  1.807771
# 230         목공  1.802526
# 257         비데  1.798323
# 232      기타 공구  1.791820
#
# [423 rows x 2 columns]
# 여성 12
#       category      pred
# 315     유아동 의류  2.490750
# 325    유아동 주얼리  2.446625
# 303   위생/건강 용품  2.436338
# 145        PSP  2.420176
# 3      여성 언더웨어  2.416277
# ..         ...       ...
# 230         목공  1.597978
# 258         욕조  1.571455
# 232      기타 공구  1.562357
# 257         비데  1.560799
# 248  기타 자동차 용품  1.557318
#
# [423 rows x 2 columns]
# 여성 22
#       category      pred
# 315     유아동 의류  2.694158
# 303   위생/건강 용품  2.683558
# 325    유아동 주얼리  2.656182
# 3      여성 언더웨어  2.647366
# 145        PSP  2.619168
# ..         ...       ...
# 230         목공  1.784366
# 258         욕조  1.765345
# 232      기타 공구  1.754625
# 257         비데  1.754320
# 248  기타 자동차 용품  1.750778
#
# [423 rows x 2 columns]
# 여성 32
#       category      pred
# 315     유아동 의류  2.293098
# 7      남성 언더웨어  2.269706
# 3      여성 언더웨어  2.255841
# 325    유아동 주얼리  2.254420
# 320     임상부 용품  2.249215
# ..         ...       ...
# 243        장난감  1.429848
# 232      기타 공구  1.413597
# 258         욕조  1.411889
# 257         비데  1.405346
# 248  기타 자동차 용품  1.395473
#
# [423 rows x 2 columns]
# 여성 42
#       category      pred
# 420      기타 문구  2.141620
# 3      여성 언더웨어  2.126246
# 7      남성 언더웨어  2.119535
# 6        남성 잠옷  2.111003
# 303   위생/건강 용품  2.074150
# ..         ...       ...
# 232      기타 공구  1.226051
# 245      세차 용품  1.209556
# 258         욕조  1.201269
# 257         비데  1.200541
# 248  기타 자동차 용품  1.180823
#
# [423 rows x 2 columns]
# 여성 52
#         category      pred
# 315       유아동 의류  2.581762
# 325      유아동 주얼리  2.530998
# 303     위생/건강 용품  2.517807
# 145          PSP  2.503503
# 310  기타 유아 외출 용품  2.478264
# ..           ...       ...
# 230           목공  1.616993
# 258           욕조  1.616257
# 248    기타 자동차 용품  1.603289
# 257           비데  1.602943
# 232        기타 공구  1.597371
#
# [423 rows x 2 columns]
# 여성 62
#       category      pred
# 420      기타 문구  2.240610
# 3      여성 언더웨어  2.224757
# 7      남성 언더웨어  2.214528
# 6        남성 잠옷  2.208965
# 303   위생/건강 용품  2.180956
# ..         ...       ...
# 232      기타 공구  1.316011
# 245      세차 용품  1.299949
# 258         욕조  1.291678
# 257         비데  1.291662
# 248  기타 자동차 용품  1.270990
#
# [423 rows x 2 columns]
# 여성 72
#         category      pred
# 315       유아동 의류  2.568861
# 325      유아동 주얼리  2.502473
# 145          PSP  2.501135
# 303     위생/건강 용품  2.450508
# 310  기타 유아 외출 용품  2.437624
# ..           ...       ...
# 248    기타 자동차 용품  1.535702
# 233        퍼즐/블록  1.529844
# 257           비데  1.527063
# 232        기타 공구  1.509878
# 230           목공  1.504219
#
# [423 rows x 2 columns]

# %%
# 아래는 테스트중인 코드입니다. (svd 알고리즘) / https://www.fun-coding.org/recommend_basic6.html

# %%
view_matrix = view_matrix.fillna(0)
matrix_values = view_matrix.values
user_view_mean = np.mean(matrix_values, axis=1)

matrix_user_mean = matrix_values - user_view_mean.reshape(-1, 1)

# %%
from scipy.sparse.linalg import svds

user, sigma, vt = svds(matrix_user_mean, k = 80)
sigma = np.diag(sigma)

svd_user_prediction = np.dot(np.dot(user, sigma), vt) + user_view_mean.reshape(-1, 1)


test = list(category_dict.items())
test.sort(key=lambda x:x[0])
# print(test)

test2 = [x[1] for x in test]
# print(test2)
results = []
for i in range(0, 1140, 20):
#     print(df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'], test2[svd_user_prediction[i].argmax()])
#     results.append([df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'], test2[svd_user_prediction[i].argmax()]])
#     print(df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'])
    result = svd_user_prediction[i]
    result_df = pd.DataFrame(result, columns=['pred'])
    result_df['category'] = result_df.index
    result_df['category'] = result_df['category'].apply(lambda x: test2[x])
    result_df = result_df.sort_values(by='pred', ascending=False)
#     print(result_df)
    results.append([df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'], result_df])
#     result.sort()
#     result = result[-10:]
#     print(result)
# print(len(svd_user_prediction[1139]))

results.sort(key=lambda x: x[0])
for result in results:
    print(result[0], result[1], result[2])
    print(result[3])

# results.sort(key=lambda x: x[0])
# for result in results:
#     print(result)
# Out:
# 90001 M 10
#          pred  category
# 193  4.233460  기타 거실 가구
# 201  4.128613     아동 책장
# 206  3.536523        책장
# 224  3.394818        액자
# 221  3.290532      블라인드
# ..        ...       ...
# 271 -0.381265    눈건강 용품
# 14  -0.388669     남성 구두
# 42  -0.394019        팔찌
# 44  -0.576211     여성 장갑
# 4   -0.627159     남성 상의
#
# [423 rows x 2 columns]
# 90021 M 10
#          pred  category
# 420  3.766659     기타 문구
# 409  3.060728    예술/디자인
# 408  2.989141  문학/과학/경영
# 404  2.966257    유아동 도서
# 419  2.216143     사무 용품
# ..        ...       ...
# 185 -0.275010     피부 케어
# 12  -0.327964    여성 실내화
# 114 -0.339688   휴대폰 케이스
# 44  -0.352518     여성 장갑
# 23  -0.370819       단지갑
#
# [423 rows x 2 columns]
# 90041 M 10
#          pred     category
# 380  3.158081       자전거 부품
# 386  3.123360           텐트
# 330  2.724182     기타 수영 용품
# 379  2.691279          자전거
# 401  2.658583        요가 용품
# ..        ...          ...
# 378 -0.307144  기타 스키/보드 용품
# 9   -0.322740        여성 구두
# 15  -0.329164      남성 캐주얼화
# 357 -0.416129          탁구대
# 384 -0.433575       낚시 소모품
#
# [423 rows x 2 columns]
# 90061 M 10
#          pred  category
# 175  3.250037  기타 생활 가전
# 178  3.106411       이어폰
# 176  3.050323       스피커
# 229  2.805187        기타
# 181  2.763340     냉방 기구
# ..        ...       ...
# 9   -0.446343     여성 구두
# 117 -0.536461   휴대폰 배터리
# 419 -0.544479     사무 용품
# 121 -0.674605        PC
# 4   -0.790621     남성 상의
#
# [423 rows x 2 columns]
# 90081 M 20
#          pred    category
# 193  3.590044    기타 거실 가구
# 227  3.584043          솜류
# 175  3.454413    기타 생활 가전
# 225  3.418942  기타 인테리어 소품
# 168  3.111671          TV
# ..        ...         ...
# 404 -0.334997      유아동 도서
# 43  -0.345415     기타 액세서리
# 373 -0.439299         등산화
# 44  -0.468234       여성 장갑
# 190 -0.514308    기타 침실 가구
#
# [423 rows x 2 columns]
# 90101 M 20
#          pred  category
# 412  4.195988     기타 도서
# 406  3.909162    소설/만화책
# 408  2.876808  문학/과학/경영
# 409  2.750583    예술/디자인
# 415  2.495967      블루레이
# ..        ...       ...
# 146 -0.272867       닌텐도
# 405 -0.278232     학습/교육
# 140 -0.315974       SSD
# 374 -0.339160     등산 잡화
# 220 -0.392351        커튼
#
# [423 rows x 2 columns]
# 90121 M 20
#          pred  category
# 216  3.639745     기타 침구
# 193  3.544649  기타 거실 가구
# 188  3.139966        장롱
# 200  3.087431  아동 책상/의자
# 227  2.997339        솜류
# ..        ...       ...
# 10  -0.379778   여성 캐주얼화
# 140 -0.421763       SSD
# 147 -0.449832       Wii
# 380 -0.464979    자전거 부품
# 149 -0.505572    게임 타이틀
#
# [423 rows x 2 columns]
# 90141 M 20
#          pred  category
# 24   2.993420    여성용 가방
# 55   2.974591    여성용 시계
# 39   2.691499       귀걸이
# 42   2.571391        팔찌
# 40   2.436730       목걸이
# ..        ...       ...
# 129 -0.324026       노트북
# 14  -0.426533     남성 구두
# 8   -0.429252        기타
# 145 -0.510036       PSP
# 125 -0.542309  모니터 주변기기
#
# [423 rows x 2 columns]
# 90161 M 30
#          pred  category
# 118  4.067477    스마트 워치
# 146  3.952778       닌텐도
# 123  3.740636   PC 액세서리
# 139  3.432914       HDD
# 417  3.332813     필기 용품
# ..        ...       ...
# 332 -0.399326       골프공
# 216 -0.424441     기타 침구
# 411 -0.431754      전공서적
# 407 -0.452600  여행/취미/레저
# 115 -0.816910  휴대폰 보호필름
#
# [423 rows x 2 columns]
# 90181 M 30
#          pred  category
# 407  3.963823  여행/취미/레저
# 408  3.897061  문학/과학/경영
# 409  3.723078    예술/디자인
# 410  2.934018        잡지
# 45   2.569935     남성 장갑
# ..        ...       ...
# 192 -0.271161       테이블
# 61  -0.323556  스킨/토너/로션
# 39  -0.340299       귀걸이
# 130 -0.358148  노트북 액세서리
# 122 -0.376158     PC 부품
#
# [423 rows x 2 columns]
# 90201 M 30
#          pred  category
# 44   4.834372     여성 장갑
# 41   4.402872       팬던트
# 11   4.101784    여성 운동화
# 24   4.075860    여성용 가방
# 47   4.023527     여성 벨트
# ..        ...       ...
# 375 -0.435023  기타 등산 용품
# 181 -0.460275     냉방 기구
# 196 -0.469948  기타 주방 가구
# 55  -0.524383    여성용 시계
# 182 -0.606659  기타 계절 가전
#
# [423 rows x 2 columns]
# 90221 M 40
#          pred  category
# 412  4.018753     기타 도서
# 410  3.850593        잡지
# 419  3.701512     사무 용품
# 405  3.211954     학습/교육
# 404  3.094095    유아동 도서
# ..        ...       ...
# 203 -0.316671    아동 서랍장
# 414 -0.332771       DVD
# 179 -0.344188  기타 음향 가전
# 0   -0.373309     여성 상의
# 173 -0.380374      의류관리
#
# [423 rows x 2 columns]
# 90241 M 40
#          pred category
# 122  3.567717    PC 부품
# 126  3.519222       기타
# 124  3.460534      모니터
# 118  3.329219   스마트 워치
# 121  3.100883       PC
# ..        ...      ...
# 420 -0.444403    기타 문구
# 197 -0.459160       헹거
# 221 -0.547355     블라인드
# 205 -0.583488    책상/의자
# 50  -0.701685    여성 양말
#
# [423 rows x 2 columns]
# 90261 M 40
#          pred category
# 418  4.031487    문구 용품
# 417  2.922179    필기 용품
# 9    2.871157    여성 구두
# 405  2.849462    학습/교육
# 11   2.428372   여성 운동화
# ..        ...      ...
# 70  -0.296696   클렌징 워터
# 336 -0.326237    운동 용품
# 63  -0.374482  기타 스킨케어
# 67  -0.429638   기타 선케어
# 18  -0.447498  남성 기능성화
#
# [423 rows x 2 columns]
# 90281 M 50
#          pred  category
# 330  3.300784  기타 수영 용품
# 344  3.241342       글러브
# 345  2.784426     야구 배트
# 358  2.669998     탁구 라켓
# 359  2.363858  기타 탁구 용품
# ..        ...       ...
# 363 -0.364421       점수판
# 131 -0.393178       마우스
# 30  -0.451574    여성용 모자
# 385 -0.466605  기타 낚시 용품
# 4   -0.470582     남성 상의
#
# [423 rows x 2 columns]
# 90301 M 50
#          pred  category
# 417  4.183420     필기 용품
# 407  3.510458  여행/취미/레저
# 411  3.460726      전공서적
# 30   2.906457    여성용 모자
# 408  2.902957  문학/과학/경영
# ..        ...       ...
# 63  -0.403398   기타 스킨케어
# 97  -0.412222    바디 클렌저
# 83  -0.418187    페이스 소품
# 95  -0.472359    손발톱정리기
# 360 -0.487711      배드민턴
#
# [423 rows x 2 columns]
# 90321 M 50
#          pred category
# 405  3.081316    학습/교육
# 311  2.852080    안전 용품
# 322  2.726789   유아동 잡화
# 313  2.711399    유아 가구
# 315  2.632259   유아동 의류
# ..        ...      ...
# 221 -0.356835     블라인드
# 417 -0.391850    필기 용품
# 119 -0.398197   스마트 밴드
# 413 -0.532363       음반
# 420 -0.680687    기타 문구
#
# [423 rows x 2 columns]
# 90341 M 60
#          pred  category
# 410  3.587214        잡지
# 418  3.030067     문구 용품
# 405  2.776407     학습/교육
# 419  2.570447     사무 용품
# 0    2.536514     여성 상의
# ..        ...       ...
# 129 -0.327748       노트북
# 83  -0.390563    페이스 소품
# 115 -0.399515  휴대폰 보호필름
# 89  -0.485568         팩
# 373 -0.507561       등산화
#
# [423 rows x 2 columns]
# 90361 M 60
#          pred   category
# 29   4.119222  기타 헤어액세서리
# 43   3.576031    기타 액세서리
# 0    3.554431      여성 상의
# 50   3.491458      여성 양말
# 9    3.477545      여성 구두
# ..        ...        ...
# 5   -0.462496      남성 하의
# 15  -0.528430    남성 캐주얼화
# 10  -0.531546    여성 캐주얼화
# 31  -0.580305     남성용 모자
# 201 -0.586677      아동 책장
#
# [423 rows x 2 columns]
# 90381 M 60
#          pred category
# 16   3.100879   남성 운동화
# 31   3.072826   남성용 모자
# 118  2.937218   스마트 워치
# 45   2.723820    남성 장갑
# 15   2.706347  남성 캐주얼화
# ..        ...      ...
# 344 -0.432023      글러브
# 328 -0.460349      수영모
# 32  -0.628244    공용 모자
# 57  -0.665181    공용 시계
# 10  -0.924386  여성 캐주얼화
#
# [423 rows x 2 columns]
# 90401 M 70
#          pred  category
# 28   3.315833  헤어밴드/핀/끈
# 138  3.138537   기타 주변기기
# 40   2.992031       목걸이
# 144  2.894042   플레이스테이션
# 116  2.865449   휴대폰 충전기
# ..        ...       ...
# 63  -0.447703   기타 스킨케어
# 62  -0.450140    에센스/크림
# 25  -0.531470    남성용 가방
# 85  -0.540567     헤어 소품
# 17  -0.613347    남성 실내화
#
# [423 rows x 2 columns]
# 90421 M 70
#          pred    category
# 225  3.900407  기타 인테리어 소품
# 212  3.821715          타일
# 219  3.594361          기타
# 169  3.294164        프로젝터
# 216  3.206423       기타 침구
# ..        ...         ...
# 297 -0.421505         이유식
# 186 -0.445249    기타 미용 가전
# 283 -0.449410         안마기
# 200 -0.489518    아동 책상/의자
# 185 -0.572285       피부 케어
#
# [423 rows x 2 columns]
# 90441 M 70
#          pred  category
# 408  2.985423  문학/과학/경영
# 417  2.895914     필기 용품
# 119  2.797549    스마트 밴드
# 420  2.564414     기타 문구
# 15   2.365184   남성 캐주얼화
# ..        ...       ...
# 404 -0.339682    유아동 도서
# 12  -0.359026    여성 실내화
# 329 -0.365988       수영복
# 336 -0.432826     운동 용품
# 149 -0.432916    게임 타이틀
#
# [423 rows x 2 columns]
# 90501 F 10
#          pred   category
# 420  2.800632      기타 문구
# 411  2.798625       전공서적
# 417  2.053426      필기 용품
# 4    1.991592      남성 상의
# 114  1.463574    휴대폰 케이스
# ..        ...        ...
# 47  -0.242345      여성 벨트
# 43  -0.271641    기타 액세서리
# 20  -0.278288   기타 신발 용품
# 332 -0.278390        골프공
# 29  -0.290950  기타 헤어액세서리
#
# [423 rows x 2 columns]
# 90521 F 10
#          pred  category
# 406  3.949664    소설/만화책
# 328  2.572307       수영모
# 344  2.393491       글러브
# 330  2.304380  기타 수영 용품
# 417  1.921882     필기 용품
# ..        ...       ...
# 335 -0.263335     헬스 기구
# 4   -0.272668     남성 상의
# 363 -0.326420       점수판
# 381 -0.457909  자전거 안전용품
# 123 -0.463116   PC 액세서리
#
# [423 rows x 2 columns]
# 90541 F 10
#          pred  category
# 328  2.776833       수영모
# 343  2.715881       야구공
# 338  2.590783       축구공
# 344  2.368909       글러브
# 339  2.279800       축구화
# ..        ...       ...
# 132 -0.383770       키보드
# 385 -0.394606  기타 낚시 용품
# 127 -0.462197    태블릿 PC
# 0   -0.479458     여성 상의
# 373 -0.563902       등산화
#
# [423 rows x 2 columns]
# 90561 F 10
#          pred category
# 4    2.701875    남성 상의
# 0    2.605637    여성 상의
# 16   2.591925   남성 운동화
# 15   2.536850  남성 캐주얼화
# 45   2.515208    남성 장갑
# ..        ...      ...
# 97  -0.349899   바디 클렌저
# 76  -0.352791    파운데이션
# 212 -0.363399       타일
# 101 -0.400928    샴푸/린스
# 90  -0.474922  마사지크림/젤
#
# [423 rows x 2 columns]
# 90581 F 20
#          pred  category
# 358  3.062912     탁구 라켓
# 357  3.058034       탁구대
# 379  3.057505       자전거
# 330  3.052227  기타 수영 용품
# 336  2.810906     운동 용품
# ..        ...       ...
# 363 -0.346023       점수판
# 374 -0.383992     등산 잡화
# 402 -0.452397   필라테스 용품
# 381 -0.507711  자전거 안전용품
# 388 -0.511574  기타 캠핑 용품
#
# [423 rows x 2 columns]
# 90601 F 20
#          pred  category
# 408  3.882813  문학/과학/경영
# 418  3.800037     문구 용품
# 114  2.157773   휴대폰 케이스
# 115  1.929040  휴대폰 보호필름
# 406  1.839333    소설/만화책
# ..        ...       ...
# 375 -0.244879  기타 등산 용품
# 45  -0.245543     남성 장갑
# 411 -0.250806      전공서적
# 28  -0.292209  헤어밴드/핀/끈
# 50  -0.391823     여성 양말
#
# [423 rows x 2 columns]
# 90621 F 20
#          pred  category
# 328  2.928478       수영모
# 329  2.879229       수영복
# 10   2.808479   여성 캐주얼화
# 41   2.766043       팬던트
# 330  2.709868  기타 수영 용품
# ..        ...       ...
# 380 -0.361090    자전거 부품
# 25  -0.376814    남성용 가방
# 72  -0.411395    기타 클렌징
# 31  -0.488722    남성용 모자
# 385 -0.504945  기타 낚시 용품
#
# [423 rows x 2 columns]
# 90641 F 20
#          pred     category
# 128  4.696342  태블릿 PC 액세서리
# 406  3.146967       소설/만화책
# 142  3.042574      기타 저장장치
# 125  2.991134     모니터 주변기기
# 148  2.983827         XBOX
# ..        ...          ...
# 45  -0.357353        남성 장갑
# 360 -0.415562         배드민턴
# 404 -0.427266       유아동 도서
# 372 -0.478158        등산 의류
# 10  -0.626908      여성 캐주얼화
#
# [423 rows x 2 columns]
# 90661 F 30
#          pred   category
# 387  3.978784         랜턴
# 372  3.091166      등산 의류
# 374  2.940408      등산 잡화
# 382  2.799738  기타 자전거 용품
# 329  2.757451        수영복
# ..        ...        ...
# 420 -0.404098      기타 문구
# 407 -0.442308   여행/취미/레저
# 41  -0.449795        팬던트
# 400 -0.534194       요가매트
# 48  -0.716546      남성 벨트
#
# [423 rows x 2 columns]
# 90681 F 30
#          pred   category
# 380  3.076553     자전거 부품
# 373  2.912511        등산화
# 386  2.804510         텐트
# 387  2.786376         랜턴
# 382  2.323574  기타 자전거 용품
# ..        ...        ...
# 419 -0.334272      사무 용품
# 361 -0.418331        테니스
# 358 -0.419891      탁구 라켓
# 332 -0.680432        골프공
# 329 -0.703664        수영복
#
# [423 rows x 2 columns]
# 90701 F 30
#          pred  category
# 268  2.629430     의료 용품
# 270  2.270179   재활운동 용품
# 271  2.240406    눈건강 용품
# 269  2.225104  냉온/찜질 용품
# 408  2.205327  문학/과학/경영
# ..        ...       ...
# 400 -0.398048      요가매트
# 334 -0.433592  기타 골프 용품
# 360 -0.448290      배드민턴
# 331 -0.651873     골프 클럽
# 332 -0.752614       골프공
#
# [423 rows x 2 columns]
# 90721 F 40
#          pred   category
# 198  3.685600        수납장
# 188  3.554118         장롱
# 204  3.546383   기타 아동 가구
# 223  3.514734         시계
# 213  3.235746  기타 DIY 자재
# ..        ...        ...
# 125 -0.314522   모니터 주변기기
# 123 -0.379003    PC 액세서리
# 41  -0.397756        팬던트
# 0   -0.476693      여성 상의
# 16  -0.656528     남성 운동화
#
# [423 rows x 2 columns]
# 90741 F 40
#          pred   category
# 200  4.117832   아동 책상/의자
# 193  3.694100   기타 거실 가구
# 227  3.581844         솜류
# 211  3.475366         벽지
# 228  3.355975         수예
# ..        ...        ...
# 29  -0.250710  기타 헤어액세서리
# 5   -0.259763      남성 하의
# 419 -0.307009      사무 용품
# 116 -0.332808    휴대폰 충전기
# 144 -0.376616    플레이스테이션
#
# [423 rows x 2 columns]
# 90761 F 40
#          pred   category
# 1    4.285182      여성 하의
# 32   3.975634      공용 모자
# 0    3.826002      여성 상의
# 38   3.725783         반지
# 43   3.640756    기타 액세서리
# ..        ...        ...
# 131 -0.288743        마우스
# 45  -0.334988      남성 장갑
# 23  -0.419728        단지갑
# 207 -0.453385  기타 사무용 가구
# 14  -0.688804      남성 구두
#
# [423 rows x 2 columns]
# 90781 F 50
#          pred  category
# 380  3.482672    자전거 부품
# 386  3.252591        텐트
# 373  3.111281       등산화
# 400  2.924906      요가매트
# 379  2.884331       자전거
# ..        ...       ...
# 369 -0.397428    마라톤 용품
# 347 -0.410186  기타 야구 용품
# 115 -0.446396  휴대폰 보호필름
# 359 -0.476225  기타 탁구 용품
# 346 -0.509373     야구 의류
#
# [423 rows x 2 columns]
# 90801 F 50
#          pred     category
# 386  3.436330           텐트
# 400  3.357157         요가매트
# 388  3.297905     기타 캠핑 용품
# 380  3.156561       자전거 부품
# 402  3.116116      필라테스 용품
# ..        ...          ...
# 377 -0.315179        스키 장비
# 359 -0.344959     기타 탁구 용품
# 378 -0.475817  기타 스키/보드 용품
# 343 -0.636376          야구공
# 385 -0.781561     기타 낚시 용품
#
# [423 rows x 2 columns]
# 90821 F 50
#          pred  category
# 411  4.210770      전공서적
# 408  4.196588  문학/과학/경영
# 412  3.866194     기타 도서
# 9    3.230534     여성 구두
# 406  3.170063    소설/만화책
# ..        ...       ...
# 129 -0.304300       노트북
# 171 -0.328605  기타 영상 가전
# 48  -0.353531     남성 벨트
# 5   -0.381956     남성 하의
# 108 -0.578339     여성 향수
#
# [423 rows x 2 columns]
# 90841 F 60
#          pred  category
# 48   2.954614     남성 벨트
# 119  2.066664    스마트 밴드
# 56   2.042666    남성용 시계
# 45   1.807053     남성 장갑
# 16   1.714685    남성 운동화
# ..        ...       ...
# 28  -0.332671  헤어밴드/핀/끈
# 3   -0.341568   여성 언더웨어
# 404 -0.361252    유아동 도서
# 329 -0.382645       수영복
# 40  -0.410799       목걸이
#
# [423 rows x 2 columns]
# 90861 F 60
#          pred  category
# 118  3.784952    스마트 워치
# 129  3.779518       노트북
# 130  3.513741  노트북 액세서리
# 146  3.475862       닌텐도
# 411  3.421084      전공서적
# ..        ...       ...
# 184 -0.303875     두피 케어
# 185 -0.312901     피부 케어
# 186 -0.337800  기타 미용 가전
# 183 -0.360904     헤어 케어
# 11  -0.573634    여성 운동화
#
# [423 rows x 2 columns]
# 90881 F 60
#          pred  category
# 11   3.433087    여성 운동화
# 44   3.384531     여성 장갑
# 10   3.130833   여성 캐주얼화
# 43   2.849982   기타 액세서리
# 9    2.779183     여성 구두
# ..        ...       ...
# 362 -0.327306       스쿼시
# 360 -0.341582      배드민턴
# 34  -0.400526       손수건
# 347 -0.413512  기타 야구 용품
# 32  -0.767407     공용 모자
#
# [423 rows x 2 columns]
# 90901 F 70
#          pred  category
# 420  3.970981     기타 문구
# 408  3.063409  문학/과학/경영
# 411  2.974612      전공서적
# 118  2.895471    스마트 워치
# 419  2.691714     사무 용품
# ..        ...       ...
# 40  -0.338743       목걸이
# 414 -0.357707       DVD
# 146 -0.396528       닌텐도
# 50  -0.415489     여성 양말
# 178 -0.471377       이어폰
#
# [423 rows x 2 columns]
# 90921 F 70
#          pred     category
# 167  3.083735     기타 주방 가전
# 310  2.505562  기타 유아 외출 용품
# 322  2.400987       유아동 잡화
# 222  2.378506           조명
# 314  2.351362       신생아 의류
# ..        ...          ...
# 190 -0.388165     기타 침실 가구
# 115 -0.395615     휴대폰 보호필름
# 404 -0.443448       유아동 도서
# 57  -0.455124        공용 시계
# 214 -0.456952           베개
#
# [423 rows x 2 columns]
# 90941 F 70
#          pred  category
# 376  3.378923   스노보드 장비
# 337  2.966607  기타 헬스 용품
# 366  2.699196     보호 용품
# 369  2.679720    마라톤 용품
# 373  2.651758       등산화
# ..        ...       ...
# 32  -0.683356     공용 모자
# 401 -0.714721     요가 용품
# 30  -0.745280    여성용 모자
# 20  -0.890187  기타 신발 용품
# 4   -0.891406     남성 상의
#
# [423 rows x 2 columns]
# 91001 C 100
#          pred  category
# 131  1.263098       마우스
# 142  1.198513   기타 저장장치
# 125  1.187921  모니터 주변기기
# 127  1.163542    태블릿 PC
# 129  1.148309       노트북
# ..        ...       ...
# 191 -0.172049        소파
# 337 -0.205638  기타 헬스 용품
# 30  -0.211547    여성용 모자
# 43  -0.249545   기타 액세서리
# 376 -0.274974   스노보드 장비
#
# [423 rows x 2 columns]
# 91011 C 100
#          pred   category
# 380  1.233430     자전거 부품
# 376  1.227623    스노보드 장비
# 382  1.161331  기타 자전거 용품
# 388  1.145177   기타 캠핑 용품
# 373  1.119524        등산화
# ..        ...        ...
# 10  -0.159285    여성 캐주얼화
# 330 -0.168808   기타 수영 용품
# 360 -0.169224       배드민턴
# 20  -0.173237   기타 신발 용품
# 411 -0.251688       전공서적
#
# [423 rows x 2 columns]
# 91041 C 100
#          pred     category
# 336  1.397758        운동 용품
# 337  1.307310     기타 헬스 용품
# 343  1.234780          야구공
# 335  1.214269        헬스 기구
# 338  1.190853          축구공
# ..        ...          ...
# 47  -0.146038        여성 벨트
# 15  -0.162349      남성 캐주얼화
# 380 -0.186628       자전거 부품
# 384 -0.242494       낚시 소모품
# 272 -0.247516  물리치료/저주파 용품
#
# [423 rows x 2 columns]
# 91071 C 100
#          pred  category
# 182  1.060355  기타 계절 가전
# 180  1.053959     난방 기구
# 174  1.022867       청소기
# 167  1.018994  기타 주방 가전
# 181  1.010618     냉방 기구
# ..        ...       ...
# 292 -0.156752    발건강 용품
# 294 -0.166536   정원/원예용품
# 230 -0.187941        목공
# 232 -0.189435     기타 공구
# 231 -0.224896        접착
#
# [423 rows x 2 columns]
# 91091 C 100
#          pred  category
# 296  0.586155        분유
# 297  0.574264       이유식
# 305  0.562020  스킨/바디 용품
# 307  0.560264     목용 용품
# 299  0.535243       기저귀
# ..        ...       ...
# 165 -0.152141       냉장고
# 178 -0.167618       이어폰
# 409 -0.181161    예술/디자인
# 10  -0.196957   여성 캐주얼화
# 39  -0.223337       귀걸이
#
# [423 rows x 2 columns]
# 91111 C 100
#          pred  category
# 201  1.148133     아동 책장
# 214  1.123082        베개
# 187  1.092043        침대
# 198  1.073632       수납장
# 196  1.070342  기타 주방 가구
# ..        ...       ...
# 404 -0.094657    유아동 도서
# 119 -0.097017    스마트 밴드
# 145 -0.108777       PSP
# 233 -0.113852     퍼즐/블록
# 234 -0.132616  프라모델/피규어
#
# [423 rows x 2 columns]
# 91131 C 100
#          pred category
# 239  1.109451   강아지 사료
# 286  1.092919      옷걸이
# 266  1.088770  건광관리 용품
# 242  1.087279   고양이 간식
# 283  1.078741      안마기
# ..        ...      ...
# 23  -0.162999      단지갑
# 132 -0.163326      키보드
# 194 -0.174111    식탁/의자
# 170 -0.185559  영상 플레이어
# 113 -0.190836      피쳐폰
#
# [423 rows x 2 columns]
# 91151 C 100
#          pred category
# 4    0.852468    남성 상의
# 5    0.532347    남성 하의
# 2    0.330727    여성 잠옷
# 8    0.324302       기타
# 7    0.303806  남성 언더웨어
# ..        ...      ...
# 64  -0.102006      선케어
# 373 -0.110517      등산화
# 43  -0.132317  기타 액세서리
# 23  -0.143270      단지갑
# 57  -0.231087    공용 시계
#
# [423 rows x 2 columns]
# 91161 C 100
#          pred  category
# 404  1.069084    유아동 도서
# 409  1.060046    예술/디자인
# 408  1.032242  문학/과학/경영
# 412  1.023312     기타 도서
# 406  1.018666    소설/만화책
# ..        ...       ...
# 380 -0.087487    자전거 부품
# 21  -0.099982       장지갑
# 321 -0.135653       임부복
# 319 -0.143489     수유 용품
# 320 -0.173810    임상부 용품
#
# [423 rows x 2 columns]
# 91191 C 100
#          pred  category
# 104  1.197704  기타 헤어 케어
# 71   1.186249     폼 클렌징
# 67   1.170398    기타 선케어
# 70   1.161187    클렌징 워터
# 91   1.109642  기타 마스크/팩
# ..        ...       ...
# 362 -0.098574       스쿼시
# 407 -0.099545  여행/취미/레저
# 125 -0.107576  모니터 주변기기
# 26  -0.111396    여행용 가방
# 411 -0.131472      전공서적
#
# [423 rows x 2 columns]
# 91211 C 100
#          pred  category
# 11   1.309278    여성 운동화
# 40   1.271608       목걸이
# 42   1.188850        팔찌
# 32   1.185799     공용 모자
# 43   1.179037   기타 액세서리
# ..        ...       ...
# 388 -0.162726  기타 캠핑 용품
# 15  -0.181436   남성 캐주얼화
# 70  -0.183870    클렌징 워터
# 88  -0.209399    마스크 시트
# 1   -0.251131     여성 하의
#
# [423 rows x 2 columns]
