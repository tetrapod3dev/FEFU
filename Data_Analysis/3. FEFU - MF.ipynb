# %%
import pandas as pd
import numpy as np
import pickle

dataframes = pd.read_pickle('recom_data/user_category_dummy.pkl')

df_counts = dataframes['view_counts']
df_users = dataframes['users']

with open('recom_data/category_dict.pkl', 'rb') as handle:
    category_dict = pickle.load(handle)

item_similarity = pd.read_pickle('recom_data/item_similarity.pkl')

# %%
category_dict[855] = '유아동 도서'
category_dict[1071] = '교육 도서'
category_dict[1072] = '학습 도서'

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')

# %%
class MF():
    def __init__(self, ratings, K, alpha, beta, iterations, verbose=True):
        """
            K: 잠재요인(latent factor)의 수
            alpha: 학습률
            beta: 정규화 계수
            iterations: SGD의 계산을 할 때의 반복 횟수
            verbose: SGD의 중간 학습과정 출력 여부
        """
        self.R = np.array(ratings)
        
        item_id_index = []
        index_item_id = []
        for i, one_id in enumerate(ratings):
            item_id_index.append([one_id, i])
            index_item_id.append([i, one_id])
        self.item_id_index = dict(item_id_index)
        self.index_item_id = dict(index_item_id)
        user_id_index = []
        index_user_id = []
        for i, one_id in enumerate(ratings.T):
            user_id_index.append([one_id, i])
            index_user_id.append([i, one_id])
        self.user_id_index = dict(user_id_index)
        self.index_user_id = dict(index_user_id)
        
        self.num_users, self.num_items = np.shape(self.R)
        self.K = K
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations
        self.verbose = verbose
        
    def rmse(self):
        """
            현재의 P행렬과 Q행렬을 가지고 Root Mean Squared Error(RMSE)를 계산
        """
        xs, ys = self.R.nonzero()
        # R에서 평점이 있는 (0이 아닌) 요소의 인덱스를 저장
        self.predictions = []
        self.errors = []
        for x, y in zip(xs, ys):
            # 평점이 존재하는 요소 (사용자 x, 아이템 y) 각각에 대해 아래 코드를 실행
            prediction = self.get_prediction(x, y)
            # 사용자 x, 아이템 y에 대한 평점 예측치를 계산
            self.predictions.append(prediction)
            # 예측값을 리스트에 추가
            self.errors.append(self.R[x, y] - prediction)
            # 실제값과 예측값의 차이를 계산해서 오차값 리스트에 추가
        self.predictions = np.array(self.predictions)
        self.errors = np.array(self.errors)
        # errors를 사용해서 RMSE를 계산
        return np.sqrt(np.mean(self.errors**2))
    
    def train(self):
        """
            정해진 횟수만큼 반복하며 P, Q, bu, bd 값을 업데이트하는 함수
        """
        # Initializing user-feature and movie-feature matrix
        # P, Q 행렬을 임의의 값으로 채움
        # 평균이 0, 표준편차가 10/K인 정규분포를 갖는 난수로 초기화
        self.P = np.random.normal(scale=1./self.K, size=(self.num_users, self.K))
        self.Q = np.random.normal(scale=1./self.K, size=(self.num_items, self.K))
        
        # Initializing the bias terms
        # 사용자 평가 경향(bu)를 0으로 초기화 / 크기는 사용자 수 (num_users)
        # 아이템 평가 경향(bd)를 0으로 초기화 / 크기는 아이템 수 (num_items)
        # 전체 평균 b를 구해서 저장
        self.b_u = np.zeros(self.num_users)
        self.b_d = np.zeros(self.num_items)
        self.b = np.mean(self.R[self.R.nonzero()])
        
        # List of training samples
        # 평점 행렬에서 값이 존재하는 요소의 인덱스들을 가져옴
        # SGD를 적용할 대상 (평점이 있는 요소의 인덱스와 평점)을 리스트로 저장
        rows, columns = self.R.nonzero()
        self.samples = [(i, j, self.R[i,j]) for i, j in zip(rows, columns)]
        
        # Stochastic gardient descent for given number of iterations
        training_process = []
        for i in range(self.iterations):
            np.random.shuffle(self.samples)
            # samples를 임의로 섞음 => 어디서 시작하는지에 따라 수렴의 속도가 달라짐
            # 매 반복마다 다양한 시작점에서 시작하기!
            self.sgd()
            # sgd를 실행 / P, Q, bu, bd가 업데이트 됨
            rmse = self.rmse()
            training_process.append((i+1, rmse))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print("반복: {0}; Train RMSE = {1:0.4f}".format(i+1, rmse))
        return training_process
    
    def get_prediction (self, i, j):
        """
            Rating prediction for user i and item j
            사용자 i의 아이템 j에 대한 평점을 예측하는 함수
        """
        prediction = self.b + self.b_u[i] + self.b_d[j] + self.P[i, :].dot(self.Q[j, :].T)
        return prediction
        
    def get_one_prediction(self, user_id, item_id):
        return self.get_prediction(self.user_id_index[user_id], self.item_id_index[item_id])
    
    def full_prediction(self):
        return self.b + self.b_u[:, np.newaxis] + self.b_d[np.newaxis, :] + self.P.dot(self.Q.T)

    def sgd(self):
        """
            Stochastic gardient descent to get optimized P and Q matrix
        """
        for i, j, r in self.samples:
            # samples에 있는 각 사용자-아이템-평점 세트에 대해서 SGD를 적용
            prediction = self.get_prediction(i, j)
            # 사용자 i, 아이템 j에 대한 평점 예측치를 구함
            e = (r - prediction)
            # 실제 평점 r과 비교해서 오차를 구함
            
            self.b_u[i] += self.alpha * (e - self.beta * self.b_u[i])
            self.b_d[j] += self.alpha * (e - self.beta * self.b_d[j])
            # 사용자 평가 경향, 아이템 평가 경향 업데이트
            
            self.P[i, :] += self.alpha * (e * self.Q[j, :] - self.beta * self.P[i, :])
            self.Q[j, :] += self.alpha * (e * self.P[i, :] - self.beta * self.Q[j, :])

# %%
view_matrix = df_counts.pivot(index='user', columns='category', values='count')
R_temp = view_matrix.fillna(0)
mf = MF(R_temp, K=100, alpha=0.01, beta=0.2, iterations=100, verbose=True)
# 인자 40개 / 반복 50회 / 학습률 0.001 / 정규화 계수 0.02로 모델을 학습합니다.
mf.train()
print(' ')
# Out:
# 반복: 10; Train RMSE = 0.8524
# 반복: 20; Train RMSE = 0.8518
# 반복: 30; Train RMSE = 0.8510
# 반복: 40; Train RMSE = 0.8473
# 반복: 50; Train RMSE = 0.8388
# 반복: 60; Train RMSE = 0.8314
# 반복: 70; Train RMSE = 0.8273
# 반복: 80; Train RMSE = 0.8248
# 반복: 90; Train RMSE = 0.8228
# 반복: 100; Train RMSE = 0.8213

# %%
print(mf.full_prediction())
# 전체 user-category의 예측값들입니다.
# Out:
# [[2.00167827 2.09482795 2.04042982 ... 2.53493103 2.13708008 2.15841162]
#  [1.73322405 1.77027175 1.78761272 ... 1.91051032 1.59569422 1.62750269]
#  [1.98729984 2.01449734 2.04809963 ... 2.09834859 1.80355931 1.83522653]
#  ...
#  [2.20382599 2.21004035 2.27720565 ... 2.18366077 1.92753196 1.95949675]
#  [2.20944556 2.21613093 2.28278798 ... 2.192187   1.93544577 1.96727523]
#  [2.20484414 2.21121158 2.27818863 ... 2.18560839 1.92925802 1.96119338]]

# %%
testers = [
    {'user_id': 90001,'gender': '남성','age': 17}, {'user_id': 90081,'gender': '남성','age': 22}, {'user_id': 90161,'gender': '남성','age': 32}, {'user_id': 90221,'gender': '남성','age': 42}, {'user_id': 90281,'gender': '남성','age': 52}, {'user_id': 90341,'gender': '남성','age': 62}, {'user_id': 90401,'gender': '남성','age': 72},
    {'user_id': 90501,'gender': '여성','age': 12}, {'user_id': 90521,'gender': '여성','age': 22}, {'user_id': 90541,'gender': '여성','age': 32}, {'user_id': 90561,'gender': '여성','age': 42}, {'user_id': 90581,'gender': '여성','age': 52}, {'user_id': 90601,'gender': '여성','age': 62}, {'user_id': 90621,'gender': '여성','age': 72}
]

# 각각의 그룹에서 한명씩 유저를 데려오고... 그 유저의 추천 카테고리를 출력해봤습니다.
# 그룹화가 아니라 개인화 추천입니다!!! 같은 그룹이어도 다른 추천 결과가 나옵니다.
for tester in testers:
    print(tester['gender'], tester['age'])
    temp_data = dict()
    
    # 전체 카테고리에 대해 예측값을 계산합니다.
    for category in R_temp:
        temp_data[category] = mf.get_one_prediction(tester['user_id'], category)

    # 예측값을 기준으로 정렬합니다.
    recomm_df = pd.DataFrame.from_dict([temp_data]).T.reset_index().rename(columns={'index': 'category', 0: 'pred'})
    temp_recomm_df = recomm_df.sort_values(by='pred', ascending=False)
    temp_recomm_df['category'] = temp_recomm_df['category'].map(lambda x: category_dict[x])
    print(temp_recomm_df)
# Out:
# 남성 17
#       category      pred
# 420      기타 문구  2.534931
# 419      사무 용품  2.423824
# 418      문구 용품  2.384112
# 3      여성 언더웨어  2.355415
# 412      기타 도서  2.323497
# ..         ...       ...
# 238  기타 관상어 용품  1.413329
# 264   기타 세탁 용품  1.402660
# 248  기타 자동차 용품  1.395205
# 247      안전 용품  1.391772
# 243        장난감  1.391548
#
# [423 rows x 2 columns]
# 남성 22
#       category      pred
# 327         인형  2.573523
# 320     임상부 용품  2.569935
# 3      여성 언더웨어  2.540266
# 8           기타  2.509890
# 319      수유 용품  2.485522
# ..         ...       ...
# 279     세제/세정제  1.671982
# 247      안전 용품  1.665354
# 243        장난감  1.662246
# 264   기타 세탁 용품  1.658584
# 248  기타 자동차 용품  1.657098
#
# [423 rows x 2 columns]
# 남성 32
#      category      pred
# 327        인형  2.773409
# 320    임상부 용품  2.718565
# 298     아기 간식  2.706104
# 319     수유 용품  2.662716
# 300       물티슈  2.651828
# ..        ...       ...
# 230        목공  1.724759
# 234  프라모델/피규어  1.719485
# 405     학습/교육  1.712060
# 235    기타 수집품  1.662006
# 410        잡지  1.644596
#
# [423 rows x 2 columns]
# 남성 42
#       category      pred
# 327         인형  2.379723
# 320     임상부 용품  2.378837
# 3      여성 언더웨어  2.338385
# 8           기타  2.309896
# 319      수유 용품  2.295762
# ..         ...       ...
# 279     세제/세정제  1.486945
# 247      안전 용품  1.481321
# 243        장난감  1.475655
# 264   기타 세탁 용품  1.475130
# 248  기타 자동차 용품  1.472059
#
# [423 rows x 2 columns]
# 남성 52
#       category      pred
# 420      기타 문구  3.023978
# 419      사무 용품  2.929418
# 418      문구 용품  2.854840
# 412      기타 도서  2.810675
# 406     소설/만화책  2.778327
# ..         ...       ...
# 238  기타 관상어 용품  1.737417
# 243        장난감  1.731901
# 264   기타 세탁 용품  1.731881
# 248  기타 자동차 용품  1.724415
# 247      안전 용품  1.718212
#
# [423 rows x 2 columns]
# 남성 62
#      category      pred
# 320    임상부 용품  2.592962
# 327        인형  2.538612
# 3     여성 언더웨어  2.514173
# 319     수유 용품  2.506629
# 6       남성 잠옷  2.471393
# ..        ...       ...
# 233     퍼즐/블록  1.738893
# 267   당뇨관리 용품  1.737293
# 243       장난감  1.729418
# 234  프라모델/피규어  1.722130
# 235    기타 수집품  1.684183
#
# [423 rows x 2 columns]
# 남성 72
#       category      pred
# 320     임상부 용품  2.631685
# 327         인형  2.613346
# 3      여성 언더웨어  2.554228
# 319      수유 용품  2.550995
# 8           기타  2.523531
# ..         ...       ...
# 264   기타 세탁 용품  1.758810
# 248  기타 자동차 용품  1.749118
# 234   프라모델/피규어  1.744137
# 243        장난감  1.742617
# 235     기타 수집품  1.709271
#
# [423 rows x 2 columns]
# 여성 12
#       category      pred
# 327         인형  2.644797
# 320     임상부 용품  2.638272
# 319      수유 용품  2.562309
# 3      여성 언더웨어  2.556480
# 8           기타  2.541914
# ..         ...       ...
# 264   기타 세탁 용품  1.735692
# 234   프라모델/피규어  1.734046
# 248  기타 자동차 용품  1.730435
# 243        장난감  1.724753
# 235     기타 수집품  1.696376
#
# [423 rows x 2 columns]
# 여성 22
#       category      pred
# 327         인형  2.612251
# 320     임상부 용품  2.590726
# 319      수유 용품  2.516865
# 298      아기 간식  2.511025
# 3      여성 언더웨어  2.509950
# ..         ...       ...
# 236     관상어 사료  1.694193
# 248  기타 자동차 용품  1.690222
# 234   프라모델/피규어  1.684999
# 243        장난감  1.684071
# 235     기타 수집품  1.643195
#
# [423 rows x 2 columns]
# 여성 32
#       category      pred
# 320     임상부 용품  2.205837
# 3      여성 언더웨어  2.196764
# 327         인형  2.156950
# 6        남성 잠옷  2.148570
# 8           기타  2.120943
# ..         ...       ...
# 279     세제/세정제  1.336055
# 264   기타 세탁 용품  1.317715
# 247      안전 용품  1.317015
# 243        장난감  1.316048
# 248  기타 자동차 용품  1.311062
#
# [423 rows x 2 columns]
# 여성 42
#       category      pred
# 3      여성 언더웨어  2.212561
# 420      기타 문구  2.186981
# 320     임상부 용품  2.168038
# 6        남성 잠옷  2.163155
# 8           기타  2.121069
# ..         ...       ...
# 236     관상어 사료  1.310912
# 264   기타 세탁 용품  1.292626
# 247      안전 용품  1.289896
# 248  기타 자동차 용품  1.288059
# 243        장난감  1.286592
#
# [423 rows x 2 columns]
# 여성 52
#       category      pred
# 327         인형  2.585473
# 320     임상부 용품  2.583472
# 3      여성 언더웨어  2.508271
# 319      수유 용품  2.505684
# 8           기타  2.491054
# ..         ...       ...
# 264   기타 세탁 용품  1.695185
# 234   프라모델/피규어  1.689774
# 248  기타 자동차 용품  1.688687
# 243        장난감  1.683170
# 235     기타 수집품  1.652609
#
# [423 rows x 2 columns]
# 여성 62
#       category      pred
# 3      여성 언더웨어  2.548288
# 420      기타 문구  2.515808
# 320     임상부 용품  2.500575
# 6        남성 잠옷  2.497461
# 8           기타  2.461379
# ..         ...       ...
# 238  기타 관상어 용품  1.637548
# 243        장난감  1.620026
# 264   기타 세탁 용품  1.618388
# 247      안전 용품  1.617149
# 248  기타 자동차 용품  1.615034
#
# [423 rows x 2 columns]
# 여성 72
#      category      pred
# 327        인형  2.699696
# 320    임상부 용품  2.650183
# 298     아기 간식  2.635934
# 319     수유 용품  2.593038
# 300       물티슈  2.580214
# ..        ...       ...
# 230        목공  1.663352
# 234  프라모델/피규어  1.657266
# 405     학습/교육  1.646906
# 235    기타 수집품  1.602596
# 410        잡지  1.582706
#
# [423 rows x 2 columns]

# %%
# 아래는 테스트중인 코드입니다. (svd 알고리즘) / https://www.fun-coding.org/recommend_basic6.html

# %%
view_matrix = view_matrix.fillna(0)
matrix_values = view_matrix.values
user_view_mean = np.mean(matrix_values, axis=1)

matrix_user_mean = matrix_values - user_view_mean.reshape(-1, 1)

# %%
from scipy.sparse.linalg import svds

user, sigma, vt = svds(matrix_user_mean, k = 80)
sigma = np.diag(sigma)

svd_user_prediction = np.dot(np.dot(user, sigma), vt) + user_view_mean.reshape(-1, 1)

# %%
test = list(category_dict.items())
test.sort(key=lambda x:x[0])
test2 = [x[1] for x in test]

results = []
for i in range(0, 1140, 20):
    result = svd_user_prediction[i]
    result_df = pd.DataFrame(result, columns=['pred'])
    result_df['category'] = result_df.index
    result_df['category'] = result_df['category'].apply(lambda x: test2[x])
    result_df = result_df.sort_values(by='pred', ascending=False)
    results.append([df_users.loc[i]['user'], df_users.loc[i]['gender'], df_users.loc[i]['age'], result_df])

results.sort(key=lambda x: x[0])
for result in results:
    print(result[0], result[1], result[2])
    print(result[3])
# Out:
# 90001 M 10
#          pred     category
# 360  3.464397         배드민턴
# 329  3.422307          수영복
# 343  3.302728          야구공
# 328  3.222383          수영모
# 330  3.081063     기타 수영 용품
# ..        ...          ...
# 370 -0.308548        당구 용품
# 368 -0.357282        무술 용품
# 1   -0.382604        여성 하의
# 365 -0.395043  기타 스포츠 액세서리
# 420 -0.459785        기타 문구
#
# [423 rows x 2 columns]
# 90021 M 10
#          pred category
# 5    3.352858    남성 하의
# 119  3.219918   스마트 밴드
# 23   2.907891      단지갑
# 45   2.809398    남성 장갑
# 16   2.547900   남성 운동화
# ..        ...      ...
# 411 -0.389565     전공서적
# 10  -0.426326  여성 캐주얼화
# 420 -0.482190    기타 문구
# 147 -0.505034      Wii
# 44  -0.548618    여성 장갑
#
# [423 rows x 2 columns]
# 90041 M 10
#          pred     category
# 375  4.230342     기타 등산 용품
# 377  2.879508        스키 장비
# 382  2.641029    기타 자전거 용품
# 376  2.474734      스노보드 장비
# 378  2.410283  기타 스키/보드 용품
# ..        ...          ...
# 67  -0.449633       기타 선케어
# 1   -0.459524        여성 하의
# 400 -0.511007         요가매트
# 20  -0.607327     기타 신발 용품
# 15  -0.627142      남성 캐주얼화
#
# [423 rows x 2 columns]
# 90061 M 10
#          pred  category
# 206  3.579656        책장
# 222  3.563847        조명
# 203  3.495826    아동 서랍장
# 204  3.195910  기타 아동 가구
# 218  3.190123        러그
# ..        ...       ...
# 233 -0.406950     퍼즐/블록
# 235 -0.408784    기타 수집품
# 122 -0.440232     PC 부품
# 125 -0.469871  모니터 주변기기
# 39  -0.747219       귀걸이
#
# [423 rows x 2 columns]
# 90081 M 20
#          pred  category
# 406  3.669503    소설/만화책
# 417  2.967120     필기 용품
# 404  2.798300     교육 도서
# 409  2.013170    예술/디자인
# 412  1.979557     기타 도서
# ..        ...       ...
# 140 -0.349090       SSD
# 82  -0.356464   화장품 케이스
# 115 -0.362686  휴대폰 보호필름
# 205 -0.368055     책상/의자
# 0   -0.369706     여성 상의
#
# [423 rows x 2 columns]
# 90101 M 20
#          pred   category
# 405  3.763646      학습 도서
# 411  3.726370       전공서적
# 11   3.187213     여성 운동화
# 408  3.079600   문학/과학/경영
# 406  2.886139     소설/만화책
# ..        ...        ...
# 18  -0.308830    남성 기능성화
# 386 -0.346962         텐트
# 90  -0.353722    마사지크림/젤
# 382 -0.398129  기타 자전거 용품
# 6   -0.481635      남성 잠옷
#
# [423 rows x 2 columns]
# 90121 M 20
#          pred   category
# 408  3.950651   문학/과학/경영
# 420  2.897714      기타 문구
# 330  2.267173   기타 수영 용품
# 418  2.034833      문구 용품
# 360  2.028151       배드민턴
# ..        ...        ...
# 376 -0.299784    스노보드 장비
# 147 -0.328356        Wii
# 16  -0.373979     남성 운동화
# 149 -0.461259     게임 타이틀
# 382 -0.497429  기타 자전거 용품
#
# [423 rows x 2 columns]
# 90141 M 20
#          pred  category
# 119  4.608186    스마트 밴드
# 116  3.793450   휴대폰 충전기
# 117  3.713132   휴대폰 배터리
# 114  3.509398   휴대폰 케이스
# 118  3.423836    스마트 워치
# ..        ...       ...
# 32  -0.409148     공용 모자
# 204 -0.422194  기타 아동 가구
# 381 -0.467464  자전거 안전용품
# 173 -0.504282      의류관리
# 176 -0.571651       스피커
#
# [423 rows x 2 columns]
# 90161 M 30
#          pred  category
# 381  3.211756  자전거 안전용품
# 372  3.058035     등산 의류
# 388  2.901735  기타 캠핑 용품
# 270  2.807754   재활운동 용품
# 373  2.521274       등산화
# ..        ...       ...
# 369 -0.323065    마라톤 용품
# 356 -0.368309       탁구공
# 360 -0.399744      배드민턴
# 361 -0.401900       테니스
# 329 -0.432496       수영복
#
# [423 rows x 2 columns]
# 90181 M 30
#          pred category
# 0    3.866777    여성 상의
# 38   3.403061       반지
# 11   2.918377   여성 운동화
# 71   2.559238    폼 클렌징
# 78   2.323670   립 메이크업
# ..        ...      ...
# 6   -0.355149    남성 잠옷
# 23  -0.409795      단지갑
# 387 -0.417485       랜턴
# 217 -0.421848      카페트
# 16  -0.511594   남성 운동화
#
# [423 rows x 2 columns]
# 90201 M 30
#          pred category
# 410  3.925383       잡지
# 405  3.681969    학습 도서
# 412  3.222338    기타 도서
# 409  2.900761   예술/디자인
# 421  2.372898    화방 용품
# ..        ...      ...
# 30  -0.268315   여성용 모자
# 44  -0.277211    여성 장갑
# 122 -0.282126    PC 부품
# 31  -0.287999   남성용 모자
# 379 -0.353148      자전거
#
# [423 rows x 2 columns]
# 90221 M 40
#          pred   category
# 199  3.602468   기타 수납 가구
# 203  3.418969     아동 서랍장
# 188  3.366117         장롱
# 213  3.269661  기타 DIY 자재
# 217  3.223709        카페트
# ..        ...        ...
# 127 -0.365164     태블릿 PC
# 8   -0.501816         기타
# 131 -0.504354        마우스
# 121 -0.513141         PC
# 186 -0.515776   기타 미용 가전
#
# [423 rows x 2 columns]
# 90241 M 40
#          pred   category
# 418  4.062238      문구 용품
# 405  3.897578      학습 도서
# 119  3.652317     스마트 밴드
# 118  3.412552     스마트 워치
# 409  3.177053     예술/디자인
# ..        ...        ...
# 213 -0.277328  기타 DIY 자재
# 30  -0.293214     여성용 모자
# 6   -0.395473      남성 잠옷
# 404 -0.447477      교육 도서
# 329 -0.487355        수영복
#
# [423 rows x 2 columns]
# 90261 M 40
#          pred  category
# 374  3.121956     등산 잡화
# 379  3.090371       자전거
# 372  2.771139     등산 의류
# 329  2.569236       수영복
# 373  2.519159       등산화
# ..        ...       ...
# 12  -0.282923    여성 실내화
# 252 -0.289600     기타 악기
# 385 -0.338520  기타 낚시 용품
# 5   -0.628783     남성 하의
# 384 -0.673698    낚시 소모품
#
# [423 rows x 2 columns]
# 90281 M 50
#          pred category
# 129  3.797821      노트북
# 113  3.440092      피쳐폰
# 123  3.438108  PC 액세서리
# 412  3.169502    기타 도서
# 405  3.070414    학습 도서
# ..        ...      ...
# 48  -0.285375    남성 벨트
# 219 -0.285683       기타
# 63  -0.316517  기타 스킨케어
# 404 -0.332746    교육 도서
# 181 -0.549298    냉방 기구
#
# [423 rows x 2 columns]
# 90301 M 50
#          pred  category
# 411  4.121044      전공서적
# 408  4.103365  문학/과학/경영
# 405  4.058596     학습 도서
# 410  3.073168        잡지
# 418  3.021543     문구 용품
# ..        ...       ...
# 195 -0.412196    주방 수납장
# 104 -0.424124  기타 헤어 케어
# 420 -0.428823     기타 문구
# 145 -0.432561       PSP
# 110 -0.540463     공용 향수
#
# [423 rows x 2 columns]
# 90321 M 50
#          pred   category
# 30   4.231274     여성용 모자
# 11   3.854913     여성 운동화
# 29   3.793836  기타 헤어액세서리
# 1    3.754675      여성 하의
# 43   3.675947    기타 액세서리
# ..        ...        ...
# 140 -0.408174        SSD
# 56  -0.419234     남성용 시계
# 48  -0.502537      남성 벨트
# 388 -0.532191   기타 캠핑 용품
# 16  -0.700425     남성 운동화
#
# [423 rows x 2 columns]
# 90341 M 60
#          pred  category
# 330  3.515646  기타 수영 용품
# 359  3.285613  기타 탁구 용품
# 362  3.043348       스쿼시
# 360  2.990896      배드민턴
# 361  2.896204       테니스
# ..        ...       ...
# 113 -0.281641       피쳐폰
# 24  -0.315836    여성용 가방
# 385 -0.336848  기타 낚시 용품
# 339 -0.352357       축구화
# 31  -0.451700    남성용 모자
#
# [423 rows x 2 columns]
# 90361 M 60
#          pred  category
# 169  2.685775      프로젝터
# 179  2.568441  기타 음향 가전
# 166  2.137083      요리가전
# 327  2.115571        인형
# 303  2.094061  위생/건강 용품
# ..        ...       ...
# 149 -0.236408    게임 타이틀
# 1   -0.238865     여성 하의
# 408 -0.250387  문학/과학/경영
# 184 -0.255889     두피 케어
# 183 -0.386677     헤어 케어
#
# [423 rows x 2 columns]
# 90381 M 60
#          pred  category
# 418  4.119639     문구 용품
# 417  3.891105     필기 용품
# 420  3.767111     기타 문구
# 122  2.028852     PC 부품
# 114  1.883968   휴대폰 케이스
# ..        ...       ...
# 130 -0.248647  노트북 액세서리
# 407 -0.257490  여행/취미/레저
# 120 -0.262277        기타
# 150 -0.334058     기타 게임
# 143 -0.361126     PC 게임
#
# [423 rows x 2 columns]
# 90401 M 70
#          pred  category
# 328  2.808348       수영모
# 362  2.509173       스쿼시
# 343  2.301754       야구공
# 44   2.295392     여성 장갑
# 407  2.189517  여행/취미/레저
# ..        ...       ...
# 148 -0.306693      XBOX
# 146 -0.308628       닌텐도
# 410 -0.345383        잡지
# 333 -0.350095     골프 가방
# 5   -0.437765     남성 하의
#
# [423 rows x 2 columns]
# 90421 M 70
#          pred    category
# 1    3.917698       여성 하의
# 39   3.307678         귀걸이
# 57   3.083994       공용 시계
# 24   3.054374      여성용 가방
# 41   2.977210         팬던트
# ..        ...         ...
# 49  -0.408278          멜빵
# 36  -0.447172         머플러
# 382 -0.448535   기타 자전거 용품
# 119 -0.451828      스마트 밴드
# 225 -0.498763  기타 인테리어 소품
#
# [423 rows x 2 columns]
# 90441 M 70
#          pred   category
# 222  3.163390         조명
# 207  3.141545  기타 사무용 가구
# 220  2.752196         커튼
# 223  2.735010         시계
# 227  2.706616         솜류
# ..        ...        ...
# 6   -0.338256      남성 잠옷
# 113 -0.377468        피쳐폰
# 416 -0.402817      기타 음반
# 129 -0.516204        노트북
# 50  -0.604609      여성 양말
#
# [423 rows x 2 columns]
# 90501 F 10
#          pred  category
# 339  2.150245       축구화
# 5    2.135715     남성 하의
# 15   2.104870   남성 캐주얼화
# 338  2.067924       축구공
# 336  2.006708     운동 용품
# ..        ...       ...
# 130 -0.250123  노트북 액세서리
# 41  -0.262276       팬던트
# 333 -0.274889     골프 가방
# 330 -0.439003  기타 수영 용품
# 372 -0.621951     등산 의류
#
# [423 rows x 2 columns]
# 90521 F 10
#          pred  category
# 406  3.187722    소설/만화책
# 411  3.099602      전공서적
# 323  2.804564     완구/매트
# 327  2.779631        인형
# 298  2.688238     아기 간식
# ..        ...       ...
# 119 -0.323677    스마트 밴드
# 71  -0.343259     폼 클렌징
# 407 -0.347845  여행/취미/레저
# 120 -0.359579        기타
# 404 -0.574567     교육 도서
#
# [423 rows x 2 columns]
# 90541 F 10
#          pred  category
# 372  2.841112     등산 의류
# 377  2.703172     스키 장비
# 388  2.581661  기타 캠핑 용품
# 383  2.474426       낚시대
# 386  2.302961        텐트
# ..        ...       ...
# 360 -0.360137      배드민턴
# 410 -0.406428        잡지
# 45  -0.421108     남성 장갑
# 400 -0.430537      요가매트
# 402 -0.602896   필라테스 용품
#
# [423 rows x 2 columns]
# 90561 F 10
#          pred  category
# 408  3.940571  문학/과학/경영
# 118  2.903439    스마트 워치
# 5    2.243807     남성 하의
# 15   2.234417   남성 캐주얼화
# 31   2.118961    남성용 모자
# ..        ...       ...
# 410 -0.415161        잡지
# 148 -0.474965      XBOX
# 328 -0.478028       수영모
# 12  -0.507751    여성 실내화
# 44  -0.841015     여성 장갑
#
# [423 rows x 2 columns]
# 90581 F 20
#          pred  category
# 417  3.898183     필기 용품
# 418  3.856698     문구 용품
# 408  3.274860  문학/과학/경영
# 114  2.661707   휴대폰 케이스
# 149  2.640468    게임 타이틀
# ..        ...       ...
# 32  -0.453088     공용 모자
# 189 -0.455133       서랍장
# 411 -0.473182      전공서적
# 45  -0.477243     남성 장갑
# 25  -0.556211    남성용 가방
#
# [423 rows x 2 columns]
# 90601 F 20
#          pred     category
# 380  3.856177       자전거 부품
# 386  3.362658           텐트
# 379  3.099210          자전거
# 387  3.034438           랜턴
# 400  2.905825         요가매트
# ..        ...          ...
# 9   -0.296582        여성 구두
# 45  -0.354372        남성 장갑
# 377 -0.500598        스키 장비
# 376 -0.606443      스노보드 장비
# 378 -0.769366  기타 스키/보드 용품
#
# [423 rows x 2 columns]
# 90621 F 20
#          pred     category
# 119  3.544469       스마트 밴드
# 128  3.351617  태블릿 PC 액세서리
# 412  3.218645        기타 도서
# 143  2.885894        PC 게임
# 405  2.753068        학습 도서
# ..        ...          ...
# 210 -0.309083           목재
# 12  -0.327985       여성 실내화
# 179 -0.424675     기타 음향 가전
# 199 -0.495367     기타 수납 가구
# 420 -0.564992        기타 문구
#
# [423 rows x 2 columns]
# 90641 F 20
#          pred  category
# 374  3.918398     등산 잡화
# 328  3.547202       수영모
# 400  3.523702      요가매트
# 380  3.459634    자전거 부품
# 329  3.405680       수영복
# ..        ...       ...
# 383 -0.364309       낚시대
# 384 -0.388658    낚시 소모품
# 341 -0.411428     축구 의류
# 359 -0.464862  기타 탁구 용품
# 377 -0.511843     스키 장비
#
# [423 rows x 2 columns]
# 90661 F 30
#          pred     category
# 118  4.031759       스마트 워치
# 149  3.910938       게임 타이틀
# 147  3.578103          Wii
# 42   3.375980           팔찌
# 138  3.337242      기타 주변기기
# ..        ...          ...
# 35  -0.450377          넥타이
# 128 -0.469652  태블릿 PC 액세서리
# 202 -0.488676        아동 침대
# 100 -0.492368     기타 바디 케어
# 70  -0.537107       클렌징 워터
#
# [423 rows x 2 columns]
# 90681 F 30
#          pred  category
# 40   2.648584       목걸이
# 39   2.486845       귀걸이
# 9    2.406498     여성 구두
# 4    2.378896     남성 상의
# 3    2.306829   여성 언더웨어
# ..        ...       ...
# 69  -0.391752    클렌징 오일
# 111 -0.393188        기타
# 216 -0.437259     기타 침구
# 176 -0.500938       스피커
# 171 -0.646020  기타 영상 가전
#
# [423 rows x 2 columns]
# 90701 F 30
#          pred   category
# 24   4.048901     여성용 가방
# 39   3.875247        귀걸이
# 10   3.268127    여성 캐주얼화
# 38   3.258271         반지
# 30   2.729620     여성용 모자
# ..        ...        ...
# 213 -0.327889  기타 DIY 자재
# 123 -0.333681    PC 액세서리
# 330 -0.337266   기타 수영 용품
# 45  -0.350033      남성 장갑
# 147 -0.375105        Wii
#
# [423 rows x 2 columns]
# 90721 F 40
#          pred     category
# 15   3.382716      남성 캐주얼화
# 118  3.354099       스마트 워치
# 4    3.033352        남성 상의
# 20   2.985540     기타 신발 용품
# 16   2.047585       남성 운동화
# ..        ...          ...
# 378 -0.334007  기타 스키/보드 용품
# 40  -0.378505          목걸이
# 132 -0.414592          키보드
# 381 -0.446972     자전거 안전용품
# 419 -0.504542        사무 용품
#
# [423 rows x 2 columns]
# 90741 F 40
#          pred  category
# 181  3.532780     냉방 기구
# 223  3.331786        시계
# 185  3.137105     피부 케어
# 186  3.076861  기타 미용 가전
# 182  2.911537  기타 계절 가전
# ..        ...       ...
# 125 -0.299370  모니터 주변기기
# 25  -0.309449    남성용 가방
# 41  -0.322523       팬던트
# 360 -0.387956      배드민턴
# 196 -0.672125  기타 주방 가구
#
# [423 rows x 2 columns]
# 90761 F 40
#          pred  category
# 222  3.311048        조명
# 217  3.272262       카페트
# 219  3.233772        기타
# 214  3.165638        베개
# 204  2.938248  기타 아동 가구
# ..        ...       ...
# 82  -0.279200   화장품 케이스
# 121 -0.300660        PC
# 404 -0.311795     교육 도서
# 48  -0.321181     남성 벨트
# 9   -0.352089     여성 구두
#
# [423 rows x 2 columns]
# 90781 F 50
#          pred  category
# 420  4.219547     기타 문구
# 418  3.978896     문구 용품
# 417  3.926265     필기 용품
# 405  3.825084     학습 도서
# 412  3.668207     기타 도서
# ..        ...       ...
# 132 -0.338497       키보드
# 112 -0.342922      스마트폰
# 24  -0.351252    여성용 가방
# 125 -0.377647  모니터 주변기기
# 42  -0.425848        팔찌
#
# [423 rows x 2 columns]
# 90801 F 50
#          pred category
# 138  3.655228  기타 주변기기
# 126  3.538995       기타
# 127  3.507490   태블릿 PC
# 114  3.418427  휴대폰 케이스
# 118  3.255487   스마트 워치
# ..        ...      ...
# 4   -0.467215    남성 상의
# 221 -0.467989     블라인드
# 24  -0.525965   여성용 가방
# 410 -0.539490       잡지
# 420 -0.635833    기타 문구
# [423 rows x 2 columns]
# 90821 F 50
#          pred   category
# 381  4.365503   자전거 안전용품
# 374  4.090015      등산 잡화
# 372  3.601293      등산 의류
# 384  3.340642     낚시 소모품
# 382  3.274620  기타 자전거 용품
# ..        ...        ...
# 404 -0.437433      교육 도서
# 391 -0.476681         아대
# 389 -0.514313        볼링공
# 390 -0.519583        볼링화
# 379 -0.604784        자전거
#
# [423 rows x 2 columns]
# 90841 F 60
#          pred   category
# 171  3.427182   기타 영상 가전
# 213  3.239145  기타 DIY 자재
# 203  3.045895     아동 서랍장
# 188  2.848629         장롱
# 166  2.727490       요리가전
# ..        ...        ...
# 56  -0.439266     남성용 시계
# 28  -0.440491   헤어밴드/핀/끈
# 25  -0.489689     남성용 가방
# 126 -0.621872         기타
# 50  -0.669365      여성 양말
#
# [423 rows x 2 columns]
# 90861 F 60
#          pred   category
# 213  4.437935  기타 DIY 자재
# 228  4.254305         수예
# 224  4.005393         액자
# 221  3.930068       블라인드
# 173  3.884551       의류관리
# ..        ...        ...
# 138 -0.391277    기타 주변기기
# 422 -0.403134         기타
# 0   -0.416152      여성 상의
# 14  -0.452317      남성 구두
# 123 -0.504418    PC 액세서리
#
# [423 rows x 2 columns]
# 90881 F 60
#          pred  category
# 409  3.877657    예술/디자인
# 408  3.612241  문학/과학/경영
# 412  2.947200     기타 도서
# 4    2.929976     남성 상의
# 420  2.560365     기타 문구
# ..        ...       ...
# 195 -0.263571    주방 수납장
# 387 -0.272198        랜턴
# 70  -0.283563    클렌징 워터
# 218 -0.353764        러그
# 147 -0.391688       Wii
#
# [423 rows x 2 columns]
# 90901 F 70
#          pred     category
# 405  4.033123        학습 도서
# 408  2.931703     문학/과학/경영
# 418  2.848493        문구 용품
# 417  2.745199        필기 용품
# 304  2.020602  기타 유아 위생 용품
# ..        ...          ...
# 32  -0.183886        공용 모자
# 4   -0.185980        남성 상의
# 132 -0.202108          키보드
# 123 -0.226660      PC 액세서리
# 50  -0.340997        여성 양말
#
# [423 rows x 2 columns]
# 90921 F 70
#          pred   category
# 40   4.223436        목걸이
# 29   4.099319  기타 헤어액세서리
# 5    4.010985      남성 하의
# 23   3.794476        단지갑
# 16   3.583660     남성 운동화
# ..        ...        ...
# 411 -0.395454       전공서적
# 130 -0.397233   노트북 액세서리
# 372 -0.554188      등산 의류
# 420 -0.663041      기타 문구
# 170 -0.664673    영상 플레이어
#
# [423 rows x 2 columns]
# 90941 F 70
#          pred  category
# 418  4.093976     문구 용품
# 405  3.964247     학습 도서
# 411  3.060700      전공서적
# 407  3.048743  여행/취미/레저
# 410  3.039146        잡지
# ..        ...       ...
# 315 -0.329216    유아동 의류
# 132 -0.363639       키보드
# 346 -0.406113     야구 의류
# 419 -0.411960     사무 용품
# 140 -0.537242       SSD
#
# [423 rows x 2 columns]
# 91001 C 100
#          pred     category
# 327  2.310825           인형
# 304  2.258218  기타 유아 위생 용품
# 323  2.250910        완구/매트
# 313  2.193196        유아 가구
# 298  2.190940        아기 간식
# ..        ...          ...
# 172 -0.109401      세탁기/건조기
# 12  -0.111248       여성 실내화
# 11  -0.111882       여성 운동화
# 407 -0.132263     여행/취미/레저
# 404 -0.192101        교육 도서
#
# [423 rows x 2 columns]
# 91021 C 100
#          pred  category
# 262  2.085297     세탁 용품
# 269  2.077477  냉온/찜질 용품
# 273  2.074245        식기
# 271  2.073208    눈건강 용품
# 243  2.070856       장난감
# ..        ...       ...
# 184 -0.087212     두피 케어
# 198 -0.092831       수납장
# 174 -0.103653       청소기
# 18  -0.104150   남성 기능성화
# 206 -0.145505        책장
#
# [423 rows x 2 columns]
# 91041 C 100
#          pred     category
# 386  2.161185           텐트
# 387  2.134259           랜턴
# 375  2.129495     기타 등산 용품
# 378  2.127249  기타 스키/보드 용품
# 382  2.115726    기타 자전거 용품
# ..        ...          ...
# 198 -0.103461          수납장
# 347 -0.104679     기타 야구 용품
# 48  -0.137705        남성 벨트
# 332 -0.148503          골프공
# 271 -0.170654       눈건강 용품
#
# [423 rows x 2 columns]
# 91061 C 100
#          pred  category
# 206  2.183157        책장
# 200  2.153941  아동 책상/의자
# 228  2.135099        수예
# 211  2.124698        벽지
# 221  2.113083      블라인드
# ..        ...       ...
# 139 -0.140570       HDD
# 185 -0.143297     피부 케어
# 186 -0.153588  기타 미용 가전
# 233 -0.180141     퍼즐/블록
# 234 -0.181155  프라모델/피규어
#
# [423 rows x 2 columns]
# 91081 C 100
#          pred  category
# 404  2.231115     교육 도서
# 411  2.101706      전공서적
# 412  2.073182     기타 도서
# 406  2.039788    소설/만화책
# 414  2.038320       DVD
# ..        ...       ...
# 305 -0.146502  스킨/바디 용품
# 321 -0.228575       임부복
# 303 -0.230322  위생/건강 용품
# 320 -0.269454    임상부 용품
# 319 -0.284199     수유 용품
#
# [423 rows x 2 columns]
# 91101 C 100
#          pred    category
# 174  2.119872         청소기
# 175  2.116237    기타 생활 가전
# 167  2.099291    기타 주방 가전
# 178  2.080308         이어폰
# 179  2.060187    기타 음향 가전
# ..        ...         ...
# 230 -0.240816          목공
# 231 -0.249718          접착
# 232 -0.257737       기타 공구
# 208 -0.449762    야외테이블/의자
# 209 -0.449762  기타 아웃도어 가구
#
# [423 rows x 2 columns]
# 91121 C 100
#          pred category
# 336  2.287885    운동 용품
# 338  2.221866      축구공
# 344  2.200337      글러브
# 335  2.198038    헬스 기구
# 339  2.138851      축구화
# ..        ...      ...
# 119 -0.105601   스마트 밴드
# 48  -0.116037    남성 벨트
# 265 -0.149240  건강측정 용품
# 45  -0.157568    남성 장갑
# 384 -0.205672   낚시 소모품
#
# [423 rows x 2 columns]
# 91141 C 100
#         pred category
# 1   2.140579    여성 하의
# 0   2.040648    여성 상의
# 4   1.899727    남성 상의
# 5   1.881541    남성 하의
# 3   1.810116  여성 언더웨어
# ..       ...      ...
# 59 -0.331694    기타 시계
# 60 -0.331694       기타
# 54 -0.331694       기타
# 53 -0.340228    안경 소품
# 56 -0.365793   남성용 시계
#
# [423 rows x 2 columns]
# 91161 C 100
#          pred  category
# 68   2.172767    클렌징 크림
# 99   2.167966  바디 크림/오일
# 100  2.159665  기타 바디 케어
# 104  2.142323  기타 헤어 케어
# 62   2.120486    에센스/크림
# ..        ...       ...
# 11  -0.127779    여성 운동화
# 12  -0.150619    여성 실내화
# 47  -0.178142     여성 벨트
# 24  -0.193640    여성용 가방
# 39  -0.219442       귀걸이
#
# [423 rows x 2 columns]
# 91181 C 100
#          pred  category
# 133  2.156269       복합기
# 134  2.154474       프린터
# 135  2.135295       스캐너
# 136  2.111960   네트워크 장비
# 137  2.097245       소모품
# ..        ...       ...
# 198 -0.083942       수납장
# 206 -0.093055        책장
# 229 -0.101650        기타
# 100 -0.104649  기타 바디 케어
# 57  -0.113173     공용 시계
#
# [423 rows x 2 columns]
# 91201 C 100
#          pred  category
# 9    2.140538     여성 구두
# 32   2.123611     공용 모자
# 47   2.115201     여성 벨트
# 14   2.111527     남성 구두
# 55   2.109477    여성용 시계
# ..        ...       ...
# 97  -0.105016    바디 클렌저
# 104 -0.112316  기타 헤어 케어
# 5   -0.113223     남성 하의
# 4   -0.163200     남성 상의
# 0   -0.163831     여성 상의
#
# [423 rows x 2 columns]
